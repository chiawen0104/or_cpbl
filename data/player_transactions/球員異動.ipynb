# %%
from datetime import datetime
import pandas as pd
import copy

# %%
startDate = datetime(2022, 4, 2, 0, 0, 0).date()

# %%
def createDate(mm, dd):
    return datetime(2022, mm, dd, 0, 0, 0).date()

# %% [markdown]
# ## Lions

# %%
lions = {createDate(5, 22): 
    ["江辰晏", "李其峰", "邱浩鈞", "羅昂", "施子謙", "布雷克", "胡智為", 
    "柯瑞", "姚杰宏", "楊孟沅", "江國謙", "張肇元", "柯育民", "陳重羽", "林子豪", "施冠宇", 
    "陳鏞基", "潘傑楷", "林祖傑", "林靖凱", "陳重廷", "高國慶", "李丞齡", "邱智呈", "陳傑憲", 
    "江亮緯", "胡金龍"]}
playerCntLions = 27

changeLogLions = [
    {
        "timestamp": createDate(5, 21),
        "type": "remove",
        "players": ["張肇元"]
    },
    {
        "timestamp": createDate(5, 18),
        "type": "add",
        "players": ["古林睿煬"]
    }, 
    {
        "timestamp": createDate(5, 15),
        "type": "remove",
        "players": ["江辰晏"]
    }, 
    {
        "timestamp": createDate(5, 15),
        "type": "add",
        "players": ["吳桀睿"]
    },
    {
        "timestamp": createDate(5, 14),
        "type": "remove",
        "players": ["李其峰", "邱浩鈞", "姚杰宏", "江國謙", "林祖傑", "江亮緯"]
    },
    {
        "timestamp": createDate(5, 14),
        "type": "add",
        "players": ["陳韻文", "劉軒荅", "劉予承", "江承峰", "林岱安"]
    },
    {
        "timestamp": createDate(5, 12),
        "type": "add",
        "players": ["羅暐捷"]
    },
    {
        "timestamp": createDate(5, 11),
        "type": "remove",
        "players": ["林岱安"]
    }, 
    {
        "timestamp": createDate(5, 11),
        "type": "add",
        "players": ["江辰晏"]
    },
    {
        "timestamp": createDate(5, 1),
        "type": "remove",
        "players": ["江辰晏", "胡金龍"]
    },
    {
        "timestamp": createDate(5, 1),
        "type": "add",
        "players": ["林岱安", "王鏡銘"]
    },
    {
        "timestamp": createDate(4, 30),
        "type": "remove",
        "players": ["古林睿煬"]
    },
    {
        "timestamp": createDate(4, 30),
        "type": "add",
        "players": ["江辰晏"]
    }, 
    {
        "timestamp": createDate(4, 26),
        "type": "remove",
        "players": ["江辰晏"]
    },
    {
        "timestamp": createDate(4, 26),
        "type": "add",
        "players": ["潘武雄"]
    },
    {
        "timestamp": createDate(4, 25),
        "type": "remove",
        "players": ["林子豪"]
    },
    {
        "timestamp": createDate(4, 23),
        "type": "add",
        "players": ["胡金龍"]
    },
    {
        "timestamp": createDate(4, 22),
        "type": "remove",
        "players": ["柯瑞"]
    },
    {
        "timestamp": createDate(4, 22),
        "type": "add",
        "players": ["邱浩鈞"]
    },
    {
        "timestamp": createDate(4, 21),
        "type": "remove",
        "players": ["楊孟沅"]
    },
    {
        "timestamp": createDate(4, 21),
        "type": "add",
        "players": ["林子崴"]
    },
    {
        "timestamp": createDate(4, 18),
        "type": "remove",
        "players": ["布雷克", "高國慶", "潘傑楷", "吳桀睿"]
    },
    {
        "timestamp": createDate(4, 18),
        "type": "add",
        "players": ["郭阜林", "何恆佑", "許哲晏"]
    },
    {
        "timestamp": createDate(4, 16),
        "type": "add",
        "players": ["古林睿煬"]
    },
    {
        "timestamp": createDate(4, 15),
        "type": "remove",
        "players": ["羅昂", "江承峰", "郭阜林"]
    },
    {
        "timestamp": createDate(4, 15),
        "type": "add",
        "players": ["林子豪"]
    },
    {
        "timestamp": createDate(4, 14),
        "type": "add",
        "players": ["姚宇翔", "傅于剛"]
    },
    {
        "timestamp": createDate(4, 13),
        "type": "remove",
        "players": ["傅于剛"]
    },
    {
        "timestamp": createDate(4, 13),
        "type": "add",
        "players": ["潘威倫"]
    },
    {
        "timestamp": createDate(4, 12),
        "type": "remove",
        "players": ["柯育民"]
    },
    {
        "timestamp": createDate(4, 12),
        "type": "add",
        "players": ["江辰晏"]
    },
    {
        "timestamp": createDate(4, 10),
        "type": "remove",
        "players": ["何恆佑"]
    },
    {
        "timestamp": createDate(4, 10),
        "type": "add",
        "players": ["羅薩"]
    },
    {
        "timestamp": createDate(4, 8),
        "type": "remove",
        "players": ["古林睿煬", "羅暐捷"]
    },
    {
        "timestamp": createDate(4, 8),
        "type": "add",
        "players": ["楊孟沅", "蘇智傑"]
    },
    {
        "timestamp": createDate(4, 5),
        "type": "remove",
        "players": ["胡金龍"]
    },
    {
        "timestamp": createDate(4, 5),
        "type": "add",
        "players": ["江國謙"]
    },
    {
        "timestamp": createDate(4, 4),
        "type": "remove",
        "players": ["潘威倫"]
    },
    {
        "timestamp": createDate(4, 4),
        "type": "add",
        "players": ["林焌翰"]
    },
    {
        "timestamp": startDate,
        "type": "remove",
        "players": ["楊孟沅", "江辰晏"]
    }
]

for log in changeLogLions:
    allKeys = [t for t in lions.keys()]
    timestamp = log["timestamp"]
    if timestamp in allKeys:
        nowPlayers = copy.deepcopy(lions[timestamp])
    else:
        nowPlayers = copy.deepcopy(lions[allKeys[-1]])

    if log["type"] == "add":
        for player in log["players"]:
            nowPlayers[playerCntLions] = player
            playerCntLions += 1
    if log["type"] == "remove":
        for player in log["players"]:
            nowPlayers.remove(player)
            nowPlayers.append(None)
            playerCntLions -= 1
        
    lions[timestamp] = nowPlayers
    print("change log", timestamp, "success")

pd.DataFrame(lions)
# Out:
# change log 2022-05-21 success
# change log 2022-05-18 success
# change log 2022-05-15 success
# change log 2022-05-15 success
# change log 2022-05-14 success
# change log 2022-05-14 success
# change log 2022-05-12 success
# change log 2022-05-11 success
# change log 2022-05-11 success
# change log 2022-05-01 success
# change log 2022-05-01 success
# change log 2022-04-30 success
# change log 2022-04-30 success
# change log 2022-04-26 success
# change log 2022-04-26 success
# change log 2022-04-25 success
# change log 2022-04-23 success
# change log 2022-04-22 success
# change log 2022-04-22 success
# change log 2022-04-21 success
# change log 2022-04-21 success
# change log 2022-04-18 success
# change log 2022-04-18 success
# change log 2022-04-16 success
# change log 2022-04-15 success
# change log 2022-04-15 success
# change log 2022-04-14 success
# change log 2022-04-13 success
# change log 2022-04-13 success
# change log 2022-04-12 success
# change log 2022-04-12 success
# ...

# %% [markdown]
# ## Monkeys

# %%
monkeys = {createDate(5, 24): 
    ["蘇俊璋", "黃偉晟", "陳冠宇", "蘇俊宇", "朱俊祥", "王溢正", "許峻暘", 
    "索沙", "王躍霖", "賴鴻誠", "豪勁", "黃子鵬", "林泓育", "張閔勛", "嚴宏鈞", "梁家榮", 
    "林承飛", "郭永維", "陳俊秀", "林立", "朱育賢", "馬傑森", "蔡鎮宇", "成晉", "邱丹", 
    "藍寅倫", "陳晨威", None]}
playerCntMonkeys = 27

changeLogMonkeys = [
    {
        "timestamp": createDate(5, 22),
        "type": "remove",
        "players": ["陳冠宇"]
    }, 
    {
        "timestamp": createDate(5, 22),
        "type": "add",
        "players": ["莊昕諺"]
    },
    {
        "timestamp": createDate(5, 19),
        "type": "remove",
        "players": ["莊昕諺"]
    }, 
    {
        "timestamp": createDate(5, 19),
        "type": "add",
        "players": ["林子崴"]
    },
    {
        "timestamp": createDate(5, 17),
        "type": "remove",
        "players": ["林子崴"]
    },
    {
        "timestamp": createDate(5, 14),
        "type": "remove",
        "players": ["黃子鵬"]
    }, 
    {
        "timestamp": createDate(5, 14),
        "type": "add",
        "players": ["邱駿威"]
    },
    {
        "timestamp": createDate(5, 12),
        "type": "add",
        "players": ["霸林爵"]
    },
    {
        "timestamp": createDate(5, 10),
        "type": "remove",
        "players": ["邱駿威"]
    }, 
    {
        "timestamp": createDate(5, 10),
        "type": "add",
        "players": ["黃子鵬"]
    },
    {
        "timestamp": createDate(5, 9),
        "type": "add",
        "players": ["邱駿威"]
    },
    {
        "timestamp": createDate(5, 8),
        "type": "remove",
        "players": ["邱駿威"]
    },
    {
        "timestamp": createDate(5, 6),
        "type": "remove",
        "players": ["索沙"]
    },
    {
        "timestamp": createDate(5, 4),
        "type": "add",
        "players": ["狂威"]
    },
    {
        "timestamp": createDate(5, 3),
        "type": "remove",
        "players": ["林承飛", "蘇俊璋"]
    }, 
    {
        "timestamp": createDate(5, 2),
        "type": "add",
        "players": ["林智平"]
    },
    {
        "timestamp": createDate(4, 24),
        "type": "add",
        "players": ["林子崴"]
    },
    {
        "timestamp": createDate(4, 21),
        "type": "remove",
        "players": ["林子崴"]
    },
    {
        "timestamp": createDate(4, 17),
        "type": "add",
        "players": ["陳冠宇"]
    },
    {
        "timestamp": createDate(4, 15),
        "type": "remove",
        "players": ["朱育賢"]
    }, 
    {
        "timestamp": createDate(4, 15),
        "type": "add",
        "players": ["林承飛"]
    },
    {
        "timestamp": createDate(4, 14),
        "type": "remove",
        "players": ["許峻暘"]
    },
    {
        "timestamp": createDate(4, 11),
        "type": "add",
        "players": ["陳禹勳"]
    }, 
    {
        "timestamp": createDate(4, 10),
        "type": "remove",
        "players": ["黃偉晟"]
    }, 
    {
        "timestamp": createDate(4, 10),
        "type": "add",
        "players": ["曾仁和"]
    },
    {
        "timestamp": createDate(4, 9),
        "type": "remove",
        "players": ["曾仁和"]
    }, 
    {
        "timestamp": createDate(4, 9),
        "type": "add",
        "players": ["萬昭清"]
    },
    {
        "timestamp": createDate(4, 8),
        "type": "remove",
        "players": ["霸林爵"]
    },
    {
        "timestamp": createDate(4, 7),
        "type": "remove",
        "players": ["陳冠宇"]
    },
    {
        "timestamp": createDate(4, 5),
        "type": "remove",
        "players": ["狂威"]
    }, 
    {
        "timestamp": createDate(4, 5),
        "type": "add",
        "players": ["廖健富"]
    },
    {
        "timestamp": startDate,
        "type": "remove",
        "players": ["廖健富"]
    }, 
]

for log in changeLogMonkeys:
    allKeys = [t for t in monkeys.keys()]
    timestamp = log["timestamp"]
    if timestamp in allKeys:
        nowPlayers = copy.deepcopy(monkeys[timestamp])
    else:
        nowPlayers = copy.deepcopy(monkeys[allKeys[-1]])

    if log["type"] == "add":
        for player in log["players"]:
            nowPlayers[playerCntMonkeys] = player
            playerCntMonkeys += 1
            typeStr = "降二軍"
    if log["type"] == "remove":
        for player in log["players"]:
            nowPlayers.remove(player)
            nowPlayers.append(None)
            playerCntMonkeys -= 1
            typeStr = "升一軍"
        
    monkeys[timestamp] = nowPlayers
    print(timestamp, log["players"], typeStr, "total", playerCntMonkeys, "players")

pd.DataFrame(monkeys)
# Out:
# 2022-05-22 ['陳冠宇'] 升一軍 total 26 players
# 2022-05-22 ['莊昕諺'] 降二軍 total 27 players
# 2022-05-19 ['莊昕諺'] 升一軍 total 26 players
# 2022-05-19 ['林子崴'] 降二軍 total 27 players
# 2022-05-17 ['林子崴'] 升一軍 total 26 players
# 2022-05-14 ['黃子鵬'] 升一軍 total 25 players
# 2022-05-14 ['邱駿威'] 降二軍 total 26 players
# 2022-05-12 ['霸林爵'] 降二軍 total 27 players
# 2022-05-10 ['邱駿威'] 升一軍 total 26 players
# 2022-05-10 ['黃子鵬'] 降二軍 total 27 players
# 2022-05-09 ['邱駿威'] 降二軍 total 28 players
# 2022-05-08 ['邱駿威'] 升一軍 total 27 players
# 2022-05-06 ['索沙'] 升一軍 total 26 players
# 2022-05-04 ['狂威'] 降二軍 total 27 players
# 2022-05-03 ['林承飛', '蘇俊璋'] 升一軍 total 25 players
# 2022-05-02 ['林智平'] 降二軍 total 26 players
# 2022-04-24 ['林子崴'] 降二軍 total 27 players
# 2022-04-21 ['林子崴'] 升一軍 total 26 players
# 2022-04-17 ['陳冠宇'] 降二軍 total 27 players
# 2022-04-15 ['朱育賢'] 升一軍 total 26 players
# 2022-04-15 ['林承飛'] 降二軍 total 27 players
# 2022-04-14 ['許峻暘'] 升一軍 total 26 players
# 2022-04-11 ['陳禹勳'] 降二軍 total 27 players
# ...

# %% [markdown]
# ## Brothers

# %%
brothers = {createDate(5, 24): 
    ["廖乙忠", "鄭凱文", "泰迪", "李振昌", "林丞軒", "德保拉", "象魔力", 
    "楊志龍", "呂彥青", "陳柏豪", "吳哲源", "陳家駒", "高宇杰", "黃鈞聲", "王威晨", "王政順",
    "杜家明", "許基宏", "江坤宇", "岳東華", "陳子豪", "李聖裕", "陳文杰", "張志豪", "周思齊", 
    "詹子賢", "岳政華", None]}
playerCntBrothers = 27

changeLogBrothers = [
    {
        "timestamp": createDate(5, 22),
        "type": "remove",
        "players": ["林丞軒"]
    },
    {
        "timestamp": createDate(5, 17),
        "type": "add",
        "players": ["吳俊偉"]
    },
    {
        "timestamp": createDate(5, 16),
        "type": "add",
        "players": ["蔡齊哲"]
    },
    {
        "timestamp": createDate(4, 23),
        "type": "remove",
        "players": ["蔡齊哲"]
    },
    {
        "timestamp": createDate(4, 19),
        "type": "remove",
        "players": ["廖乙忠"]
    },
    {
        "timestamp": createDate(4, 19),
        "type": "add",
        "players": ["官大元"]
    },
    {
        "timestamp": createDate(4, 17),
        "type": "remove",
        "players": ["黃鈞聲", "杜家明"]
    },
    {
        "timestamp": createDate(4, 17),
        "type": "add",
        "players": ["彭識穎", "潘志芳"]
    },
    {
        "timestamp": createDate(4, 12),
        "type": "remove",
        "players": ["德保拉"]
    },
    {
        "timestamp": createDate(4, 12),
        "type": "add",
        "players": ["福來喜"]
    },
    {
        "timestamp": createDate(4, 11),
        "type": "remove",
        "players": ["呂彥青"]
    },
    {
        "timestamp": createDate(4, 8),
        "type": "add",
        "players": ["謝榮豪"]
    },
    {
        "timestamp": createDate(4, 7),
        "type": "remove",
        "players": ["楊志龍"]
    },
    {
        "timestamp": createDate(4, 5),
        "type": "add",
        "players": ["廖乙忠"]
    },
    {
        "timestamp": createDate(4, 4),
        "type": "remove",
        "players": ["廖乙忠"]
    },
    {
        "timestamp": createDate(4, 4),
        "type": "add",
        "players": ["杜家明"]
    },
    {
        "timestamp": createDate(4, 3),
        "type": "remove",
        "players": ["鄭凱文"]
    },
    {
        "timestamp": createDate(4, 2),
        "type": "remove",
        "players": ["象魔力"]
    }
]

for log in changeLogBrothers:
    allKeys = [t for t in brothers.keys()]
    timestamp = log["timestamp"]
    if timestamp in allKeys:
        nowPlayers = copy.deepcopy(brothers[timestamp])
    else:
        nowPlayers = copy.deepcopy(brothers[allKeys[-1]])

    if log["type"] == "add":
        for player in log["players"]:
            nowPlayers[playerCntBrothers] = player
            playerCntBrothers += 1
    if log["type"] == "remove":
        for player in log["players"]:
            nowPlayers.remove(player)
            nowPlayers.append(None)
            playerCntBrothers -= 1
        
    brothers[timestamp] = nowPlayers
    print("change log", timestamp, "success")

pd.DataFrame(brothers)
# Out:
# change log 2022-05-22 success
# change log 2022-05-17 success
# change log 2022-05-16 success
# change log 2022-04-23 success
# change log 2022-04-19 success
# change log 2022-04-19 success
# change log 2022-04-17 success
# change log 2022-04-17 success
# change log 2022-04-12 success
# change log 2022-04-12 success
# change log 2022-04-11 success
# change log 2022-04-08 success
# change log 2022-04-07 success
# change log 2022-04-05 success
# change log 2022-04-04 success
# change log 2022-04-04 success
# change log 2022-04-03 success
# change log 2022-04-02 success
#    2022-05-24 2022-05-22 2022-05-17 2022-05-16 2022-04-23 2022-04-19  \
# 0         廖乙忠        廖乙忠        廖乙忠        廖乙忠        廖乙忠        鄭凱文
# 1         鄭凱文        鄭凱文        鄭凱文        鄭凱文        鄭凱文         泰迪
# 2          泰迪         泰迪         泰迪         泰迪         泰迪        李振昌
# 3         李振昌        李振昌        李振昌        李振昌        李振昌        德保拉
# ...

# %% [markdown]
# ## Guardians

# %%
guardians = {createDate(5, 24): 
    ["陳鴻文", "張耿豪", "郭俊麟", "王尉永", "岳少華", "范米特", "李建勳",
    "歐書誠", "陳冠勳", "曾峻岳", "威迪茲", "陳仕朋", "林琨笙", "張進德", "戴培峰", "王勝偉", 
    "莊韋恩", "蔣智賢", "李宗賢", "葉竹軒", "范國宸", "董子恩", "陳真", "申皓瑋", "張冠廷",
    "孔念恩", None, None]}
playerCntGuardians = 26

changeLogGuardians = [
    {
        "timestamp": createDate(5, 21),
        "type": "add",
        "players": ["王苡丞"]
    },
    {
        "timestamp": createDate(5, 19),
        "type": "remove",
        "players": ["張耿豪", "陳鴻文"]
    }, 
    {
        "timestamp": createDate(5, 19),
        "type": "add",
        "players": ["霸帝士", "江國豪"]
    }, 
    {
        "timestamp": createDate(5, 17),
        "type": "remove",
        "players": ["張冠廷"]
    },
    {
        "timestamp": createDate(5, 17),
        "type": "add",
        "players": ["王正棠"]
    },
    {
        "timestamp": createDate(5, 14),
        "type": "remove",
        "players": ["陳真", "張進德", "莊韋恩"]
    },
    {
        "timestamp": createDate(5, 13),
        "type": "add",
        "players": ["楊瑞承", "高孝儀", "陽耀勳"]
    },
    {
        "timestamp": createDate(5, 10),
        "type": "remove",
        "players": ["孔念恩"]
    }, 
    {
        "timestamp": createDate(5, 10),
        "type": "add",
        "players": ["于森旭"]
    },
    {
        "timestamp": createDate(5, 9),
        "type": "remove",
        "players": ["霸帝士", "郭俊麟", "陳冠勳"]
    }, 
    {
        "timestamp": createDate(5, 9),
        "type": "add",
        "players": ["優瑪", "高國輝", "江少慶", "楊晉豪"]
    },
    {
        "timestamp": createDate(5, 7),
        "type": "remove",
        "players": ["葉竹軒", "王勝偉", "陽耀勳"]
    }, 
    {
        "timestamp": createDate(5, 7),
        "type": "add",
        "players": ["王詩聰"]
    },
    {
        "timestamp": createDate(5, 5),
        "type": "add",
        "players": ["陳鴻文"]
    },
    {
        "timestamp": createDate(5, 4),
        "type": "remove",
        "players": ["蔣智賢", "岳少華"]
    },
    {
        "timestamp": createDate(5, 4),
        "type": "add",
        "players": ["游霆崴", "高國麟"]
    },
    {
        "timestamp": createDate(5, 3),
        "type": "remove",
        "players": ["歐書誠"]
    },
    {
        "timestamp": createDate(5, 3),
        "type": "add",
        "players": ["張瑞麟"]
    },
    {
        "timestamp": createDate(4, 30),
        "type": "remove",
        "players": ["高國輝", "李宗賢"]
    },
    {
        "timestamp": createDate(4, 30),
        "type": "add",
        "players": ["張進德", "莊韋恩"]
    }, 
    {
        "timestamp": createDate(4, 26),
        "type": "remove",
        "players": ["王詩聰", "楊瑞承"]
    },
    {
        "timestamp": createDate(4, 26),
        "type": "add",
        "players": ["林哲瑄", "林益全"]
    },
    {
        "timestamp": createDate(4, 25),
        "type": "remove",
        "players": ["優瑪", "高孝儀", "董子恩", "王苡丞", "莊韋恩"]
    },
    {
        "timestamp": createDate(4, 21),
        "type": "add",
        "players": ["岳少華", "霸帝士", "王勝偉", "陽耀勳", "蔣智賢"]
    },
    {
        "timestamp": createDate(4, 20),
        "type": "remove",
        "players": ["李建勳"]
    },
    {
        "timestamp": createDate(4, 18),
        "type": "add",
        "players": ["高國輝"]
    },
    {
        "timestamp": createDate(4, 14),
        "type": "remove",
        "players": ["楊晉豪", "游霆崴"]
    },
    {
        "timestamp": createDate(4, 14),
        "type": "add",
        "players": ["李宗賢", "范玉禹"]
    },
    {
        "timestamp": createDate(4, 12),
        "type": "remove",
        "players": ["張瑞麟"]
    },
    {
        "timestamp": createDate(4, 10),
        "type": "add",
        "players": ["洪聖欽"]
    },
    {
        "timestamp": createDate(4, 9),
        "type": "remove",
        "players": ["威迪茲"]
    },
    {
        "timestamp": createDate(4, 9),
        "type": "add",
        "players": ["歐書誠"]
    },
    {
        "timestamp": startDate,
        "type": "remove",
        "players": ["洪聖欽", "陳仕朋"]
    },
    {
        "timestamp": startDate,
        "type": "add",
        "players": ["李子強", "李建勳"]
    }
]

for log in changeLogGuardians:
    allKeys = [t for t in guardians.keys()]
    timestamp = log["timestamp"]
    if timestamp in allKeys:
        nowPlayers = copy.deepcopy(guardians[timestamp])
    else:
        nowPlayers = copy.deepcopy(guardians[allKeys[-1]])

    if log["type"] == "add":
        for player in log["players"]:
            nowPlayers[playerCntGuardians] = player
            playerCntGuardians += 1
    if log["type"] == "remove":
        for player in log["players"]:
            nowPlayers.remove(player)
            nowPlayers.append(None)
            playerCntGuardians -= 1
        
    guardians[timestamp] = nowPlayers
    print("change log", timestamp, "success, total", playerCntGuardians, "players")

pd.DataFrame(guardians)
# Out:
# change log 2022-05-21 success, total 27 players
# change log 2022-05-19 success, total 25 players
# change log 2022-05-19 success, total 27 players
# change log 2022-05-17 success, total 26 players
# change log 2022-05-17 success, total 27 players
# change log 2022-05-14 success, total 24 players
# change log 2022-05-13 success, total 27 players
# change log 2022-05-10 success, total 26 players
# change log 2022-05-10 success, total 27 players
# change log 2022-05-09 success, total 24 players
# change log 2022-05-09 success, total 28 players
# change log 2022-05-07 success, total 25 players
# change log 2022-05-07 success, total 26 players
# change log 2022-05-05 success, total 27 players
# change log 2022-05-04 success, total 25 players
# change log 2022-05-04 success, total 27 players
# change log 2022-05-03 success, total 26 players
# change log 2022-05-03 success, total 27 players
# change log 2022-04-30 success, total 25 players
# change log 2022-04-30 success, total 27 players
# ...

# %% [markdown]
# ## Dragons

# %%
dragons = {createDate(5, 21): 
    ["王維中", "郭郁政", "鋼龍", "布里悍", "林羿豪", "林逸達", "伍鐸", 
    "陳冠偉", "羅華韋", "陳明軒", "王玉譜", "吉力吉撈．鞏冠", "林辰勳", "劉時豪", "蔣少宏", 
    "李凱威", "張政禹", "林智勝", "劉基鴻", "龍德力", "拿莫．伊漾", "吳東融", "石翔宇",
    "郭天信", "張祐銘", "邱辰", "陳品捷", None]}

playerCntDragons = 27

changeLogDragons = [
    {
        "timestamp": createDate(5, 19),
        "type": "remove",
        "players": ["王維中"]
    },
    {
        "timestamp": createDate(5, 19),
        "type": "add",
        "players": ["林威廷"]
    },
    {
        "timestamp": createDate(5, 18),
        "type": "add",
        "players": ["曹祐齊"]
    },
    {
        "timestamp": createDate(5, 17),
        "type": "remove",
        "players": ["曹祐齊"]
    },
    {
        "timestamp": createDate(5, 16),
        "type": "add",
        "players": ["廖任磊"]
    },
    {
        "timestamp": createDate(5, 15),
        "type": "remove",
        "players": ["廖任磊"]
    },
    {
        "timestamp": createDate(4, 27),
        "type": "remove",
        "players": ["林辰勳", "林威廷", "龍德力"]
    },
    {
        "timestamp": createDate(4, 27),
        "type": "add",
        "players": ["曾陶鎔"]
    },
    {
        "timestamp": createDate(4, 20),
        "type": "add",
        "players": ["劉昱言", "王維中"]
    },
    {
        "timestamp": createDate(4, 19),
        "type": "remove",
        "players": ["郭郁政", "林羿豪"]
    },
    {
        "timestamp": createDate(4, 19),
        "type": "add",
        "players": ["廖任磊", "呂偉晟"]
    },
    {
        "timestamp": createDate(4, 18),
        "type": "remove",
        "players": ["曾陶鎔"]
    },
    {
        "timestamp": createDate(4, 17),
        "type": "add",
        "players": ["董秉軒"]
    },
    {
        "timestamp": createDate(4, 15),
        "type": "remove",
        "players": ["董秉軒"]
    },
    {
        "timestamp": createDate(4, 15),
        "type": "add",
        "players": ["鈦龍"]
    },
    {
        "timestamp": createDate(4, 14),
        "type": "remove",
        "players": ["王維中"]
    },
    {
        "timestamp": createDate(4, 14),
        "type": "add",
        "players": ["林子昱"]
    },
    {
        "timestamp": createDate(4, 13),
        "type": "remove",
        "players": ["林子昱"]
    },
    {
        "timestamp": createDate(4, 9),
        "type": "add",
        "players": ["林孝程"]
    },
    {
        "timestamp": createDate(4, 7),
        "type": "remove",
        "players": ["鈦龍"]
    },
    {
        "timestamp": createDate(4, 5),
        "type": "add",
        "players": ["郭郁政"]
    },
    {
        "timestamp": createDate(4, 4),
        "type": "remove",
        "players": ["郭郁政"]
    },
    {
        "timestamp": startDate,
        "type": "remove",
        "players": ["鋼龍", "廖任磊"]
    },
    {
        "timestamp": startDate,
        "type": "add",
        "players": ["林子昱"]
    },
]

for log in changeLogDragons:
    allKeys = [t for t in dragons.keys()]
    timestamp = log["timestamp"]
    if timestamp in allKeys:
        nowPlayers = copy.deepcopy(dragons[timestamp])
    else:
        nowPlayers = copy.deepcopy(dragons[allKeys[-1]])

    if log["type"] == "add":
        for player in log["players"]:
            nowPlayers[playerCntDragons] = player
            playerCntDragons += 1
    if log["type"] == "remove":
        for player in log["players"]:
            nowPlayers.remove(player)
            nowPlayers.append(None)
            playerCntDragons -= 1
        
    dragons[timestamp] = nowPlayers
    print("change log", timestamp, "success")

pd.DataFrame(dragons)
# Out:
# change log 2022-05-19 success
# change log 2022-05-19 success
# change log 2022-05-18 success
# change log 2022-05-17 success
# change log 2022-05-16 success
# change log 2022-05-15 success
# change log 2022-04-27 success
# change log 2022-04-27 success
# change log 2022-04-20 success
# change log 2022-04-19 success
# change log 2022-04-19 success
# change log 2022-04-18 success
# change log 2022-04-17 success
# change log 2022-04-15 success
# change log 2022-04-15 success
# change log 2022-04-14 success
# change log 2022-04-14 success
# change log 2022-04-13 success
# change log 2022-04-09 success
# change log 2022-04-07 success
# change log 2022-04-05 success
# change log 2022-04-04 success
# change log 2022-04-02 success
# change log 2022-04-02 success
#    2022-05-21 2022-05-19 2022-05-18 2022-05-17 2022-05-16 2022-05-15  \
# 0         王維中        郭郁政        郭郁政        郭郁政        郭郁政        郭郁政
# 1         郭郁政         鋼龍         鋼龍         鋼龍         鋼龍         鋼龍
# ...

# %%
pd.DataFrame(lions).to_csv("./統一7-ELEVEn獅.csv")
pd.DataFrame(monkeys).to_csv("./樂天桃猿.csv")
pd.DataFrame(guardians).to_csv("./富邦悍將.csv")
pd.DataFrame(brothers).to_csv("./中信兄弟.csv")
pd.DataFrame(dragons).to_csv("./味全龍.csv")
