# %%
import json
import csv
import pandas as pd
import gurobipy as gp
from datetime import datetime, timedelta

# %%
OBP_AVG = 0.327
SLG_AVG = 0.365

FPCT_AVG = {
    '2': 0.992,
    '3': 0.993,
    '4': 0.977, 
    '5': 0.929,
    '6': 0.964,
    '7': 0.977,
    '8': 0.988,
    '9': 0.976
}

POSITION_WEIGHT = {
    '2': {"batting": 0.95, "fielding": 1.05},
    '3': {"batting": 1.21, "fielding": 0.83},
    '4': {"batting": 0.97, "fielding": 1.03},
    '5': {"batting": 0.96, "fielding": 1.04},
    '6': {"batting": 0.94, "fielding": 1.06},
    '7': {"batting": 1.02, "fielding": 0.98},
    '8': {"batting": 1.04, "fielding": 0.96},
    '9': {"batting": 1.17, "fielding": 0.85},
}

OPPONENT_WEIGHT = {
    "中信兄弟": 1.15,
    "統一7-ELEVEn獅": 1.11,
    "樂天桃猿": 0.96, 
    "富邦悍將": 0.93,
    "味全龍": 0.85
}

dataRoot = "../clean/clean_all_"
playerRoot = "../球員異動/"
scheduleRoot = "../schedule/"

teamNameMap = {
    "中信兄弟": "brothers", 
    "味全龍": "dragons",
    "富邦悍將": "guardians", 
    "統一7-ELEVEn獅": "lions",
    "樂天桃猿": "monkeys"
}

fieldMap = {
    'DH': 'DH',
    '2': 'C',
    '3': '1B',
    '4': '2B',
    '5': '3B',
    '6': 'SS',
    '7': 'LF',
    '8': 'CF',
    '9': 'RF'
}

# %% [markdown]
# ### Import Data

# %%
class Player:
    def __init__(self, name, data):
        self.name = name
        self.data = data

# %%
allData = {}
for team in teamNameMap.keys():
    with open(dataRoot + team + ".json", encoding="utf-8") as f:
        temp = []
        for line in f:
            player = json.loads(line)
            temp.append(Player(player["name"], player["data"]))
        allData[teamNameMap[team]] = temp

brothers = allData["brothers"]
dragons = allData["dragons"]
guardians = allData["guardians"]
lions = allData["lions"]
monkeys = allData["monkeys"]

# %%
playerList = {}

for team in teamNameMap.keys():
    tempDict = pd.read_csv(playerRoot + team + ".csv", header=0, index_col=0).to_dict()
    tempDict = {
        datetime.strptime(key, "%Y-%m-%d").date(): list(filter(lambda d: pd.isna(d) == False, list(value.values())))
        for key, value in tempDict.items()
    }
    playerList[teamNameMap[team]] = tempDict

# %%
def createDate(mm, dd):
    return datetime(2022, mm, dd, 0, 0, 0).date()

# %% [markdown]
# ### Calculate Parameters

# %%
# 比賽當天 27 人名單去除投手
def findPlayerList(team, date):
    minDelta = timedelta(days=100)
    playerDay = date
    for key in playerList[teamNameMap[team]].keys():
        if timedelta(days=0) <= date - key < minDelta:
            minDelta = date - key
            playerDay = key
    
    withoutPitcherList = []
    for data in allData[teamNameMap[team]]:
        withoutPitcherList.append(data.name)
    return list(filter(lambda d: d in withoutPitcherList, playerList[teamNameMap[team]][playerDay]))

# %%
# A_{ij}
def calcA(player, pos):
    if str(pos) in player.data["fielding"]["pos"].keys():
        return 1
    else:
        return 0

# %%
# F_{ij}
def calcF(player, pos):
    if str(pos) in player.data["fielding"]["pos"].keys():
        F = float(player.data["fielding"]["pos"][str(pos)]["FPCT"]) / FPCT_AVG[str(pos)]
        return F
    else:
        return 0

# %%
# B_i
def calcOPS(OBP, SLG):
    return OBP / OBP_AVG + SLG / SLG_AVG - 1

def calcB(game, player, aMonth):
    if game["date"].month == 4:
        aMonth = "Apr"
    if game["date"].month == 5:
        aMonth = "May"
    if game["date"].month == 6:
        aMonth = "Jun"
    aOppo = game["oppo"]
    aPitcher = game["pitcher"]
    aField = game["field"]

    OPSseason = float(player.data["batting"]["season"]["OPS+"])
    PAseason = int(player.data["batting"]["season"]["PA"])
    
    if "month" in player.data["batting"].keys():
        if aMonth in player.data["batting"]["month"].keys():
            if int(player.data["batting"]["month"][aMonth]["AB"]) != 0:
                OPSmonth = calcOPS(
                    float(player.data["batting"]["month"][aMonth]["OBP"]), 
                    float(player.data["batting"]["month"][aMonth]["TB"]) / float(player.data["batting"]["month"][aMonth]["AB"])
                )
                PAmonth = int(player.data["batting"]["month"][aMonth]["PA"])
            else:
                OPSmonth = OPSseason
                PAmonth = 0
        else:
            OPSmonth = OPSseason
            PAmonth = 0
    else:
        OPSmonth = OPSseason
        PAmonth = 0

    if "field" in player.data["batting"]:
        if aField in player.data["batting"]["field"].keys():
            if int(player.data["batting"]["field"][aField]["AB"]) != 0:
                OPSfield = calcOPS(
                    float(player.data["batting"]["field"][aField]["OBP"]), 
                    float(player.data["batting"]["field"][aField]["TB"]) / float(player.data["batting"]["field"][aField]["AB"])
                )
                PAfield = int(player.data["batting"]["field"][aField]["PA"])
            else:
                OPSfield = OPSseason
                PAfield = 0
        else:
            OPSfield = OPSseason
            PAfield = 0
    else:
        OPSfield = OPSseason
        PAfield = 0
    
    if "vsP" in player.data["batting"].keys():
        if aOppo in player.data["batting"]["vsP"]["data"].keys():
            if aPitcher in player.data["batting"]["vsP"]["data"][aOppo].keys():
                if int(player.data["batting"]["vsP"]["data"][aOppo][aPitcher]["AB"]) != 0:
                    OPSvsp = calcOPS(
                        float(player.data["batting"]["vsP"]["data"][aOppo][aPitcher]["OBP"]), 
                        float(player.data["batting"]["vsP"]["data"][aOppo][aPitcher]["TB"]) / float(player.data["batting"]["vsP"]["data"][aOppo][aPitcher]["AB"])
                    )
                    PAvsp = int(player.data["batting"]["vsP"]["data"][aOppo][aPitcher]["PA"])
                else:
                    OPSvsp = OPSseason
                    PAvsp = 0
            else:
                OPSvsp = OPSseason
                PAvsp = 0
        else:
            OPSvsp = OPSseason
            PAvsp = 0
    else:
        OPSvsp = OPSseason
        PAvsp = 0

    if PAseason + PAmonth + PAfield + PAvsp == 0:
        B = 0
    else:
        B = (OPSseason * PAseason + OPSmonth * PAmonth + OPSfield * PAfield + OPSvsp * PAvsp) / (PAseason + PAmonth + PAfield + PAvsp)
    return B

# V_{ij}
def calcV(game, month, player, pos):
    A = calcA(player, pos)
    B = calcB(game, player, month)
    F = calcF(player, pos)
    return (POSITION_WEIGHT[str(pos)]["batting"] * B + POSITION_WEIGHT[str(pos)]["fielding"] * F) * A

# %% [markdown]
# ### Integer Program

# %% [markdown]
# #### Stage 1

# %%
def stage1(aTeam, aGame, aMonth):
    model = gp.Model("model")

    # decision variables
    x = []
    for g in range(len(aGame)):
        todayPlayerList = findPlayerList(aTeam, aGame[g]["date"])
        singleGame = {}
        for i in range(len(todayPlayerList)):
            singlePlayer = []
            for j in range(2, 10):
                singlePlayer.append(model.addVar(lb=0, vtype="B", name="x" + str(g) + "-" + todayPlayerList[i] + "-" + str(j)))
            singleGame[todayPlayerList[i]] = singlePlayer
        x.append(singleGame)

    # objective function
    model.setObjective(gp.quicksum(
        gp.quicksum(
            gp.quicksum(
                OPPONENT_WEIGHT[aGame[g]["oppo"]] * calcV(aGame[g], aMonth, list(filter(lambda d: d.name == thisPlayer, allData[teamNameMap[aTeam]]))[0], j) * x[g][thisPlayer][j - 2]
                for j in range(2, 10)
            ) for thisPlayer in findPlayerList(aTeam, aGame[g]["date"])
        ) for g in range(len(aGame))
    ), gp.GRB.MAXIMIZE)

    # constraints
    zSum = 0
    for g in range(len(aGame)):
        todayPlayerList = findPlayerList(aTeam, aGame[g]["date"])
        zSum += OPPONENT_WEIGHT[aGame[g]["oppo"]]
        for thisPlayerName in todayPlayerList:
        
            thisPlayer = list(filter(lambda d: d.name == thisPlayerName, allData[teamNameMap[aTeam]]))[0]
                    
            # constraint 2
            model.addConstr(gp.quicksum(x[g][thisPlayerName][j - 2] for j in range(2, 10)) <= 1)

            for j in range(2, 10):
                # constraint 3
                model.addConstr(x[g][thisPlayerName][j - 2] <= calcA(thisPlayer, j))

        for j in range(2, 10):
            # constraint 1
            model.addConstr(gp.quicksum(x[g][thisPlayerName][j - 2] for thisPlayerName in todayPlayerList) <= 1)

    # constraint 4
    for thisPlayer in findPlayerList(aTeam, aGame[0]["date"]):
        if len(aGame) >= 4:
            for n in range(4, len(aGame) + 1):
                model.addConstr(
                    gp.quicksum(
                        x[g][thisPlayer][2 - 2] if thisPlayer in findPlayerList(aTeam, aGame[g]["date"]) else 0
                        for g in range(n - 4, n)
                    ) <= 3
                )

    model.optimize()

    playerName = []
    onPlayer = {}
    for g in range(len(aGame)):
        singleGame = []
        onPlayerTemp = {}
        for j in range(8):
            for name in x[g].keys():
                if x[g][name][j].x == 1:
                    singleGame.append(name)
                    onPlayerTemp[name] = { "field": str(j + 2) }
        playerName.append(singleGame)
        onPlayer[aGame[g]["date"]] = onPlayerTemp
        print("===== complete game", g, "- stage 1 =====")
    
    return playerName, onPlayer, model.objVal, model.objVal / zSum

# %% [markdown]
# #### Stage 1.5 - DH

# %%
def fillField(aTeam, game, playerName, positionType):
    candidate = list(filter(lambda d: d not in playerName, findPlayerList(aTeam, game["date"])))
    print("***** candidate:", candidate)
    findPlayerList(aTeam, game["date"])
    # 內野手
    if positionType == 1:
        for can in candidate:
            thisPlayerObject = list(filter(lambda d: d.name == can, allData[teamNameMap[aTeam]]))[0]
            for pos in ["3", "4", "5", "6"]:
                if pos in thisPlayerObject.data["fielding"]["pos"].keys():
                    return can
    # 外野手
    else:
        for can in candidate:
            thisPlayerObject = list(filter(lambda d: d.name == can, allData[teamNameMap[aTeam]]))[0]
            for pos in ["7", "8", "9"]:
                if pos in thisPlayerObject.data["fielding"]["pos"].keys():
                    return can

# %%
def stageDH(aTeam, aGame, aMonth, playerName, onPlayer):
    for g in range(len(aGame)):
        if len(playerName[g]) < 8:
            onPositionRecord = [False, False, False, False, False, False, False, False]
            for player in onPlayer[aGame[g]["date"]].keys():
                onPositionRecord[int(onPlayer[aGame[g]["date"]][player]["field"]) - 2] = True
            for i in range(len(onPositionRecord)):
                if(onPositionRecord[i] == False):
                    if i <= 4:
                        fill = fillField(aTeam, aGame[g], playerName[g], 1)
                    else:
                        fill = fillField(aTeam, aGame[g], playerName[g], 2)
                    onPlayer[aGame[g]["date"]][fill] = { "field": str(i + 2) }
                    playerName[g].append(fill)
                    onPositionRecord[i] = True

        maxB = -1
        todayPlayerList = findPlayerList(aTeam, aGame[g]["date"])
        for todayPlayer in todayPlayerList:
            if todayPlayer not in playerName[g]:
                thisPlayerObject = list(filter(lambda d: d.name == todayPlayer, allData[teamNameMap[aTeam]]))[0]
                thisB = calcB(aGame[g], thisPlayerObject, aMonth)
                if thisB > maxB:
                    DHPlayerName = thisPlayerObject.name
                    maxB = thisB
        playerName[g].append(DHPlayerName)
        onPlayer[aGame[g]["date"]][DHPlayerName] = { "field": "DH" }

        print("===== complete game", g, "- stage DH =====")
    return onPlayer, playerName

# %% [markdown]
# #### Stage 2

# %%
def stage2(aTeam, aGame, onPlayer, playerName):
    stage2Obj = []
    for g in range(len(aGame)):
        model2 = gp.Model("model2")
        
        allO = []
        y = []
        for j in range(1, 10):
            thisPlayer = list(filter(lambda d: d.name == playerName[g][j - 1], allData[teamNameMap[aTeam]]))[0]
            temp = []
            tempY = []
            for k in range(1, 10):
                if "baorder" in thisPlayer.data["batting"].keys():
                    if str(k) in thisPlayer.data["batting"]["baorder"].keys():
                        thisOrderData = thisPlayer.data["batting"]["baorder"][str(k)]
                        PA = int(thisOrderData["PA"])
                        if PA >= 30:
                            O = (int(thisOrderData["IBB"][1]) * 0.72 + int(thisOrderData["HBP"]) * 0.75 
                            + (int(thisOrderData["H"]) - int(thisOrderData["2B"]) - int(thisOrderData["3B"]) - int(thisOrderData["HR"])) * 0.9
                            + int(thisOrderData["2B"]) * 1.24 + int(thisOrderData["3B"]) * 1.56 + int(thisOrderData["HR"]) * 1.95) / PA
                        else:
                            O = thisPlayer.data["batting"]["season"]["wOBA"]
                    else:
                        O = thisPlayer.data["batting"]["season"]["wOBA"]
                else:
                    O = thisPlayer.data["batting"]["season"]["wOBA"]
                temp.append(O)
                tempY.append(model2.addVar(lb=0, vtype="B", name="y" + str(j) + "-" + str(k)))

            allO.append(temp)
            y.append(tempY)
        
        model2.setObjective(
            gp.quicksum(
                gp.quicksum(
                    allO[j - 1][k - 1] * y[j - 1][k - 1] 
                    for k in range(1, 10)
                ) 
                for j in range(1, 10)
            ),
            gp.GRB.MAXIMIZE
        )

        for k in range(1, 10):
            model2.addConstr(gp.quicksum(y[j - 1][k - 1] for j in range(1, 10)) == 1)
        for j in range(2, 10):
            model2.addConstr(gp.quicksum(y[j - 1][k - 1] for k in range(1, 10)) == 1)

        model2.optimize()
        
        for j in range(1, 10):
            for k in range(1, 10):
                if y[j - 1][k - 1].x == 1:
                    onPlayer[aGame[g]["date"]][playerName[g][j - 1]]["bat"] = k

        print("===== complete game", g, "- stage 2 =====")
        stage2Obj.append(model2.objVal)

    return onPlayer, playerName, stage2Obj

# %% [markdown]
# ### Optimization

# %% [markdown]
# #### 富邦悍將

# %%
aTeam = "富邦悍將"
scheduleList = {}
with open(scheduleRoot + aTeam + ".csv", encoding="utf-8") as csvFile:
    csvReader = csv.DictReader(csvFile)
    for row in csvReader:
        scheduleList[row["日期"]] = row

scheduleByWeek = {}
for week in range(1, 9):
    scheduleByWeek[week] = []
    for date in scheduleList.keys():
        if scheduleList[date]["\ufeff週次"] == str(week):
            scheduleByWeek[week].append({
                "date": datetime.strptime(date, "%m月%d日").date().replace(year=2022),
                "field": "".join(scheduleList[date]["場地"].split()),
                "oppo": "".join(scheduleList[date]["對手"].split()),
                "pitcher": "".join(scheduleList[date]["先發投手"].split())
            })

# %%
allResult = {}
for week in range(1, 9):
    aMonth = "Apr"
    aGame = scheduleByWeek[week]
    playerName, onPlayer, stage1Obj, stage1ObjWeight = stage1(aTeam, aGame, aMonth)
    onPlayer, playerName = stageDH(aTeam, aGame, aMonth, playerName, onPlayer)
    onPlayer, playerName, stage2Obj = stage2(aTeam, aGame, onPlayer, playerName)

    index = 0
    for date, dayPlayer in onPlayer.items():
        onPlayerList = [None] * 9
        for playerName, playerData in dayPlayer.items():
            onPlayerList[playerData["bat"] - 1] = playerName + " " + fieldMap[playerData["field"]]
        onPlayerList.extend([stage1Obj, stage1ObjWeight, stage2Obj[index]])
        onPlayer[date] = onPlayerList
        index += 1
    allResult.update(onPlayer)
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 152 rows, 128 columns and 384 nonzeros
# Model fingerprint: 0xbd08a7c0
# Variable types: 0 continuous, 128 integer (128 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 724.3449268
# Presolve removed 152 rows and 128 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 841.637 724.345
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.416365752360e+02, best bound 8.416365752360e+02, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 0 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0bfd3dd6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6742454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9028410
#
# Root relaxation: objective 3.213302e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2133016    3.21330  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2133 2.90284 2.67425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.213301587302e+00, best bound 3.213301587302e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 792 rows, 640 columns and 2048 nonzeros
# Model fingerprint: 0x1c29ecf5
# Variable types: 0 continuous, 640 integer (640 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2636.1510130
# Presolve removed 781 rows and 625 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 2971.5900835
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2971.59 2636.15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.971590083457e+03, best bound 2.971590083457e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0bfd3dd6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6742454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9028410
#
# Root relaxation: objective 3.213302e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2133016    3.21330  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2133 2.90284 2.67425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.213301587302e+00, best bound 3.213301587302e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0bfd3dd6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6742454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9028410
#
# Root relaxation: objective 3.213302e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2133016    3.21330  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2133 2.90284 2.67425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.213301587302e+00, best bound 3.213301587302e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0bfd3dd6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6742454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9028410
#
# Root relaxation: objective 3.213302e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2133016    3.21330  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2133 2.90284 2.67425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.213301587302e+00, best bound 3.213301587302e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xbc36c8c3
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.4892454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7798410
#
# Root relaxation: objective 3.090302e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0903016    3.09030  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.0903 2.77984 2.48925
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.090301587302e+00, best bound 3.090301587302e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0bfd3dd6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6742454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9028410
#
# Root relaxation: objective 3.213302e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2133016    3.21330  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2133 2.90284 2.67425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.213301587302e+00, best bound 3.213301587302e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 456 rows, 384 columns and 1152 nonzeros
# Model fingerprint: 0xb76efd01
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2168.3025364
# Presolve removed 456 rows and 384 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2512.28 2168.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.512278571308e+03, best bound 2.512278571308e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0bfd3dd6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6742454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9028410
#
# Root relaxation: objective 3.213302e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2133016    3.21330  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2133 2.90284 2.67425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.213301587302e+00, best bound 3.213301587302e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0bfd3dd6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6742454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9028410
#
# Root relaxation: objective 3.213302e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2133016    3.21330  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2133 2.90284 2.67425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.213301587302e+00, best bound 3.213301587302e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0bfd3dd6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6742454
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9028410
#
# Root relaxation: objective 3.213302e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2133016    3.21330  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2133 2.90284 2.67425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.213301587302e+00, best bound 3.213301587302e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 587 rows, 480 columns and 1500 nonzeros
# Model fingerprint: 0x00f3b94b
# Variable types: 0 continuous, 480 integer (480 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 1869.6897482
# Presolve removed 580 rows and 468 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 12 columns, 24 nonzeros
# Found heuristic solution: objective 2133.3394208
# Variable types: 0 continuous, 12 integer (12 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2133.34 1869.69
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.133339420774e+03, best bound 2.133339420774e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ***** candidate: ['林琨笙', '戴培峰', '楊晉豪', '林哲瑄', '霸帝士', '王勝偉', '陽耀勳', '蔣智賢']
# ===== complete game 0 - stage DH =====
# ***** candidate: ['林琨笙', '戴培峰', '楊晉豪', '林哲瑄', '霸帝士', '王勝偉', '陽耀勳', '蔣智賢']
# ===== complete game 1 - stage DH =====
# ***** candidate: ['林琨笙', '戴培峰', '楊晉豪', '林哲瑄', '霸帝士', '王勝偉', '陽耀勳', '蔣智賢']
# ===== complete game 2 - stage DH =====
# ***** candidate: ['戴培峰', '楊晉豪', '張進德', '林哲瑄', '霸帝士', '王勝偉', '陽耀勳', '蔣智賢']
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb33dc249
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8306824
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1034579
#
# Root relaxation: objective 3.357302e+00, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3573016    3.35730  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.3573 3.10346 2.83068
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.357301587302e+00, best bound 3.357301587302e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4bfc88e7
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7706824
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0434579
#
# Root relaxation: objective 3.297302e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2973016    3.29730  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2973 3.04346 2.77068
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.297301587302e+00, best bound 3.297301587302e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4bfc88e7
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7706824
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0434579
#
# Root relaxation: objective 3.297302e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2973016    3.29730  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2973 3.04346 2.77068
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.297301587302e+00, best bound 3.297301587302e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xe97436fa
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6636824
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9984579
#
# Root relaxation: objective 3.252302e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2523016    3.25230  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2523 2.99846 2.66368
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.252301587302e+00, best bound 3.252301587302e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 745 rows, 600 columns and 1914 nonzeros
# Model fingerprint: 0x1e131461
# Variable types: 0 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 3371.7057048
# Presolve removed 734 rows and 585 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 4130.4635132
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 4.134667e+03, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4134.6674541 4134.66745  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4134.67 4130.46 3371.71
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.134667454145e+03, best bound 4.134667454145e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb21d5e6e
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8213384
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0091841
#
# Root relaxation: objective 3.308302e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3083016    3.30830  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.3083 3.00918 2.82134
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.308301587302e+00, best bound 3.308301587302e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x216bba9d
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6543384
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9449341
#
# Root relaxation: objective 3.203302e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2033016    3.20330  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2033 2.94493 2.65434
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203301587302e+00, best bound 3.203301587302e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb21d5e6e
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8213384
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0091841
#
# Root relaxation: objective 3.308302e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3083016    3.30830  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.3083 3.00918 2.82134
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.308301587302e+00, best bound 3.308301587302e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x84d8dcf5
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9024826
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1010000
#
# Root relaxation: objective 3.209100e+00, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2090996    3.20910  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2091 3.101 2.90248
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.209099567100e+00, best bound 3.209099567100e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x84d8dcf5
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9024826
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1010000
#
# Root relaxation: objective 3.209100e+00, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2090996    3.20910  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.2091 3.101 2.90248
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.209099567100e+00, best bound 3.209099567100e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 587 rows, 480 columns and 1498 nonzeros
# Model fingerprint: 0x2e824f45
# Variable types: 0 continuous, 480 integer (480 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 1671.0268362
# Presolve removed 581 rows and 472 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2153.2074707
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2153.21 1671.03
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.153207470684e+03, best bound 2.153207470684e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x59b0c74f
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8857265
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9121341
#
# Root relaxation: objective 3.021724e+00, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0217238    3.02172  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.02172 2.91213 2.88573
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.021723809524e+00, best bound 3.021723809524e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x59b0c74f
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8857265
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9121341
#
# Root relaxation: objective 3.021724e+00, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0217238    3.02172  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.02172 2.91213 2.88573
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.021723809524e+00, best bound 3.021723809524e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x6cb7f316
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8177265
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9230000
#
# Root relaxation: objective 2.953724e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9537238    2.95372  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.95372 2.923 2.81773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.953723809524e+00, best bound 2.953723809524e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x32bd1733
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7947265
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9256087
#
# Root relaxation: objective 2.956333e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9563325    2.95633  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.95633 2.92561 2.79473
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.956332505176e+00, best bound 2.956332505176e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 634 rows, 520 columns and 1621 nonzeros
# Model fingerprint: 0x30c16f79
# Variable types: 0 continuous, 520 integer (520 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2518.9428292
# Presolve removed 628 rows and 512 columns
# Presolve time: 0.01s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2811.9266544
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2811.93 2518.94
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.811926654442e+03, best bound 2.811926654442e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x93095b24
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0000000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0262000
#
# Root relaxation: objective 3.030724e+00, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0307238    3.03072  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.03072 3.0262 3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.030723809524e+00, best bound 3.030723809524e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x044b3c68
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9530000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9792000
#
# Root relaxation: objective 3.025300e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0252996    3.02530  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.0253 2.9792 2.953
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.025299567100e+00, best bound 3.025299567100e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x044b3c68
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9530000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9792000
#
# Root relaxation: objective 3.025300e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0252996    3.02530  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.0253 2.9792 2.953
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.025299567100e+00, best bound 3.025299567100e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xa0225206
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8430000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8948087
#
# Root relaxation: objective 2.936384e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9363845    2.93638  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93638 2.89481 2.843
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.936384453228e+00, best bound 2.936384453228e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 774 rows, 624 columns and 1992 nonzeros
# Model fingerprint: 0xc7ee1c17
# Variable types: 0 continuous, 624 integer (624 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2302.6753258
# Presolve removed 763 rows and 609 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 3515.6360067
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 3.529629e+03, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3529.6288981 3529.62890  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3529.63 3515.64 2302.68
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.529628898064e+03, best bound 3.529628898064e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xe34c2322
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1360000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.13600    3.13600  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.136
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.136000000000e+00, best bound 3.136000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xa09ec89c
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9570000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9832000
#
# Root relaxation: objective 3.019000e+00, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0190000    3.01900  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.019 2.9832 2.957
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.019000000000e+00, best bound 3.019000000000e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb427bcaf
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0900000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.09000    3.09000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.090000000000e+00, best bound 3.090000000000e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x353282cc
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1030000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.10300    3.10300  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.103
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.103000000000e+00, best bound 3.103000000000e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x353282cc
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1030000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.10300    3.10300  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.103
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.103000000000e+00, best bound 3.103000000000e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====

# %%
weekResult = pd.DataFrame(allResult, index=[1, 2, 3, 4, 5, 6, 7, 8, 9, "stage 1", "stage 1 wAVG", "stage 2"])
weekResult
# Out:
#              2022-04-03 2022-04-04 2022-04-07 2022-04-08 2022-04-09  \
# 1                范國宸 RF     范國宸 RF     范國宸 RF     范國宸 RF     申皓瑋 CF
# 2                申皓瑋 CF     申皓瑋 CF     申皓瑋 CF     申皓瑋 CF     李宗賢 3B
# 3                李宗賢 3B     李宗賢 3B     李宗賢 3B     李宗賢 3B     王正棠 2B
# 4                高國麟 LF     高國麟 LF     高國麟 LF     高國麟 LF      林琨笙 C
# 5                林益全 1B     林益全 1B     林益全 1B     林益全 1B     林益全 1B
# 6                 張進德 C      張進德 C      張進德 C      張進德 C     張進德 DH
# 7                王正棠 2B     王正棠 2B     王正棠 2B     王正棠 2B     高國麟 LF
# 8                高國輝 DH     高國輝 DH     高國輝 DH     高國輝 DH     范國宸 RF
# 9                于森旭 SS     于森旭 SS     于森旭 SS     于森旭 SS     于森旭 SS
# stage 1         841.637    2971.59    2971.59    2971.59    2971.59
# stage 1 wAVG    731.858     569.27     569.27     569.27     569.27
# stage 2          3.2133     3.2133     3.2133     3.2133     3.0903
#
#              2022-04-10 2022-04-14 2022-04-15 2022-04-16 2022-04-21  ...  \
# 1                范國宸 RF     范國宸 RF     范國宸 RF     范國宸 RF     楊晉豪 3B  ...
# 2                申皓瑋 CF     申皓瑋 CF     申皓瑋 CF     申皓瑋 CF     林哲瑄 DH  ...
# 3                李宗賢 3B     李宗賢 3B     李宗賢 3B     李宗賢 3B     申皓瑋 CF  ...
# 4                高國麟 LF     高國麟 LF     高國麟 LF     高國麟 LF     王正棠 2B  ...
# 5                林益全 1B     林益全 1B     林益全 1B     林益全 1B     林益全 1B  ...
# 6                 張進德 C      張進德 C      張進德 C      張進德 C      張進德 C  ...
# 7                王正棠 2B     王正棠 2B     王正棠 2B     王正棠 2B     范國宸 RF  ...
# 8                高國輝 DH     高國輝 DH     高國輝 DH     高國輝 DH     高國麟 LF  ...
# 9                于森旭 SS     于森旭 SS     于森旭 SS     于森旭 SS     于森旭 SS  ...
# stage 1         2971.59    2512.28    2512.28    2512.28    2133.34  ...
# stage 1 wAVG     569.27    736.739    736.739    736.739    576.578  ...
# stage 2          3.2133     3.2133     3.2133     3.2133     3.3573  ...
#
#              2022-05-06 2022-05-09 2022-05-10 2022-05-12 2022-05-13  \
# 1                高國輝 LF      林琨笙 C      林琨笙 C      林琨笙 C     霸帝士 DH
# 2                申皓瑋 CF     申皓瑋 CF     申皓瑋 CF     申皓瑋 CF     申皓瑋 CF
# 3                王正棠 2B     楊瑞承 1B     楊瑞承 1B     楊瑞承 1B     李宗賢 SS
# 4                楊瑞承 1B     葉竹軒 2B     葉竹軒 2B     葉竹軒 2B     葉竹軒 2B
# 5                蔣智賢 DH     董子恩 3B     董子恩 3B     董子恩 3B     董子恩 3B
# 6                范國宸 RF     范國宸 RF     范國宸 RF     范國宸 RF     范國宸 RF
# 7                董子恩 3B     高國輝 LF     高孝儀 LF     高孝儀 LF     高孝儀 LF
# 8                 戴培峰 C     蔣智賢 DH     蔣智賢 DH     蔣智賢 DH      戴培峰 C
# 9                于森旭 SS     于森旭 SS     于森旭 SS     于森旭 SS     楊瑞承 1B
# stage 1         2153.21    2811.93    2811.93    2811.93    2811.93
# stage 1 wAVG    534.295     672.71     672.71     672.71     672.71
# stage 2         2.95633    3.03072     3.0253     3.0253    2.93638
#
#              2022-05-17 2022-05-18 2022-05-20 2022-05-21 2022-05-22
# 1                葉竹軒 2B      林琨笙 C     葉竹軒 2B     葉竹軒 2B     葉竹軒 2B
# 2                范國宸 1B     申皓瑋 CF     蔣智賢 1B     蔣智賢 1B     蔣智賢 1B
# 3                申皓瑋 CF     李宗賢 SS     申皓瑋 CF     申皓瑋 CF     申皓瑋 CF
# 4                李宗賢 SS     葉竹軒 2B     李宗賢 SS     李宗賢 SS     李宗賢 SS
# 5                 陳真 LF     董子恩 3B      陳真 LF      陳真 LF      陳真 LF
# 6                 張進德 C     張進德 DH      張進德 C      張進德 C      張進德 C
# 7                王正棠 RF     王正棠 RF     范國宸 RF     范國宸 RF     范國宸 RF
# 8                蔣智賢 DH      陳真 LF     霸帝士 DH     張冠廷 DH     張冠廷 DH
# 9                董子恩 3B     范國宸 1B     董子恩 3B     董子恩 3B     董子恩 3B
# stage 1         3529.63    3529.63    3529.63    3529.63    3529.63
# stage 1 wAVG    770.661    770.661    770.661    770.661    770.661
# stage 2           3.136      3.019       3.09      3.103      3.103
#
# [12 rows x 31 columns]

# %%
weekResult.to_csv("result/" + aTeam + ".csv", encoding='utf_8_sig')

# %% [markdown]
# #### 中信兄弟

# %%
aTeam = "中信兄弟"
scheduleList = {}
with open(scheduleRoot + aTeam + ".csv", encoding="utf-8") as csvFile:
    csvReader = csv.DictReader(csvFile)
    for row in csvReader:
        scheduleList[row["日期"]] = row

scheduleByWeek = {}
for week in range(1, 10):
    scheduleByWeek[week] = []
    for date in scheduleList.keys():
        if scheduleList[date]["\ufeff週次"] == str(week):
            scheduleByWeek[week].append({
                "date": datetime.strptime(date, "%m月%d日").date().replace(year=2022),
                "field": "".join(scheduleList[date]["場地"].split()),
                "oppo": "".join(scheduleList[date]["對手"].split()),
                "pitcher": "".join(scheduleList[date]["先發投手"].split())
            })

# %%
allResult = {}
for week in range(1, 10):
    aMonth = "Apr"
    aGame = scheduleByWeek[week]
    playerName, onPlayer, stage1Obj, stage1ObjWeight = stage1(aTeam, aGame, aMonth)
    onPlayer, playerName = stageDH(aTeam, aGame, aMonth, playerName, onPlayer)
    onPlayer, playerName, stage2Obj = stage2(aTeam, aGame, onPlayer, playerName)

    index = 0
    for date, dayPlayer in onPlayer.items():
        onPlayerList = [None] * 9
        for playerName, playerData in dayPlayer.items():
            onPlayerList[playerData["bat"] - 1] = playerName + " " + fieldMap[playerData["field"]]
        onPlayerList.extend([stage1Obj, stage1ObjWeight, stage2Obj[index]])
        onPlayer[date] = onPlayerList
        index += 1
    allResult.update(onPlayer)
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 304 rows, 256 columns and 768 nonzeros
# Model fingerprint: 0x844d52c0
# Variable types: 0 continuous, 256 integer (256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1060.7687758
# Presolve removed 289 rows and 235 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 21 columns, 42 nonzeros
# Found heuristic solution: objective 1323.6971745
# Variable types: 0 continuous, 21 integer (21 binary)
# Found heuristic solution: objective 1323.9802412
#
# Root relaxation: objective 1.326277e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1326.2766139 1326.27661  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1326.28 1323.98 1323.7 1060.77
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.326276613856e+03, best bound 1.326276613856e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x667e9dad
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8673335
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1300000
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.13000    3.13000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.13 2.86733
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.130000000000e+00, best bound 3.130000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfe78ba51
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9960002
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1300000
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.13000    3.13000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.13 2.996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.130000000000e+00, best bound 3.130000000000e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 756 rows, 608 columns and 1945 nonzeros
# Model fingerprint: 0x94c8c65a
# Variable types: 0 continuous, 608 integer (608 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 3266.0408335
# Presolve removed 741 rows and 587 columns
# Presolve time: 0.01s
# Presolved: 15 rows, 21 columns, 42 nonzeros
# Found heuristic solution: objective 3776.5071791
# Variable types: 0 continuous, 21 integer (21 binary)
#
# Root relaxation: objective 3.779035e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3779.0352598 3779.03526  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3779.04 3776.51 3266.04
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.779035259844e+03, best bound 3.779035259844e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x667e9dad
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8673335
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1300000
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.13000    3.13000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.13 2.86733
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.130000000000e+00, best bound 3.130000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xeb866e85
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7024205
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0680000
#
# Root relaxation: objective 3.072684e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0726842    3.07268  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.07268 3.068 2.70242
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.072684210526e+00, best bound 3.072684210526e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x1ac5fecf
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7444205
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1100000
#
# Root relaxation: objective 3.114684e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1146842    3.11468  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.11468 3.11 2.74442
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.114684210526e+00, best bound 3.114684210526e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xf3106243
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8730871
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1100000
#
# Root relaxation: objective 3.114684e+00, 22 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1146842    3.11468  0.00%     -    0s
#
# Explored 1 nodes (22 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.11468 3.11 2.87309
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.114684210526e+00, best bound 3.114684210526e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x1ac5fecf
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7444205
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1100000
#
# Root relaxation: objective 3.114684e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1146842    3.11468  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.11468 3.11 2.74442
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.114684210526e+00, best bound 3.114684210526e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 578 rows, 472 columns and 1475 nonzeros
# Model fingerprint: 0xcab2a244
# Variable types: 0 continuous, 472 integer (472 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2136.1352017
# Presolve removed 566 rows and 455 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 17 columns, 34 nonzeros
# Found heuristic solution: objective 2517.9561482
# Variable types: 0 continuous, 17 integer (17 binary)
#
# Root relaxation: objective 2.520152e+03, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2520.1524368 2520.15244  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2520.15 2517.96 2136.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.520152436787e+03, best bound 2.520152436787e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x1ac5fecf
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7444205
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1100000
#
# Root relaxation: objective 3.114684e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1146842    3.11468  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.11468 3.11 2.74442
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.114684210526e+00, best bound 3.114684210526e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x1ac5fecf
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7444205
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1100000
#
# Root relaxation: objective 3.114684e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1146842    3.11468  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.11468 3.11 2.74442
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.114684210526e+00, best bound 3.114684210526e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xf3106243
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8730871
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1100000
#
# Root relaxation: objective 3.114684e+00, 22 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1146842    3.11468  0.00%     -    0s
#
# Explored 1 nodes (22 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.11468 3.11 2.87309
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.114684210526e+00, best bound 3.114684210526e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xdf84ff24
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8520871
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0890000
#
# Root relaxation: objective 3.093684e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0936842    3.09368  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.09368 3.089 2.85209
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.093684210526e+00, best bound 3.093684210526e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 745 rows, 600 columns and 1920 nonzeros
# Model fingerprint: 0x3e5f9d7f
# Variable types: 0 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2467.9212087
# Presolve removed 734 rows and 585 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 2762.4987375
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 2.766241e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2766.2408368 2766.24084  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2766.24 2762.5 2467.92
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.766240836755e+03, best bound 2.766240836755e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x12ef7642
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9470002
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0810000
#
# Root relaxation: cutoff, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.08100    3.08100  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.081 2.947
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.081000000000e+00, best bound 3.081000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xaf01f881
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9130002
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0470000
#
# Root relaxation: cutoff, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.04700    3.04700  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.047 2.913
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.047000000000e+00, best bound 3.047000000000e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x12ef7642
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9470002
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0810000
#
# Root relaxation: cutoff, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.08100    3.08100  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.081 2.947
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.081000000000e+00, best bound 3.081000000000e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x12ef7642
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9470002
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0810000
#
# Root relaxation: cutoff, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.08100    3.08100  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.081 2.947
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.081000000000e+00, best bound 3.081000000000e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x12ef7642
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9470002
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0810000
#
# Root relaxation: cutoff, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.08100    3.08100  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.081 2.947
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.081000000000e+00, best bound 3.081000000000e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 429 rows, 360 columns and 1080 nonzeros
# Model fingerprint: 0x783aba0e
# Variable types: 0 continuous, 360 integer (360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1846.1687986
# Presolve removed 427 rows and 357 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 3 columns, 4 nonzeros
# Found heuristic solution: objective 2054.6154026
# Variable types: 0 continuous, 3 integer (3 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2054.62 1846.17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.054615402589e+03, best bound 2.054615402589e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xaf01f881
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9130002
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0470000
#
# Root relaxation: cutoff, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.04700    3.04700  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.047 2.913
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.047000000000e+00, best bound 3.047000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc4c18ea0
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0138195
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0810000
#
# Root relaxation: cutoff, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.08100    3.08100  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.081 3.01382
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.081000000000e+00, best bound 3.081000000000e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x12ef7642
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9470002
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0810000
#
# Root relaxation: cutoff, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         3.08100    3.08100  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.081 2.947
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.081000000000e+00, best bound 3.081000000000e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 587 rows, 480 columns and 1500 nonzeros
# Model fingerprint: 0x662d2475
# Variable types: 0 continuous, 480 integer (480 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2435.0342162
# Presolve removed 585 rows and 477 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 3 columns, 4 nonzeros
# Found heuristic solution: objective 2805.3924955
# Variable types: 0 continuous, 3 integer (3 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2805.39 2435.03
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.805392495460e+03, best bound 2.805392495460e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x51557cc3
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8580206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9920204
#
# Root relaxation: objective 3.108000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1080000    3.10800  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.108 2.99202 2.85802
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.108000000000e+00, best bound 3.108000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc52701b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8590206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9930204
#
# Root relaxation: objective 3.109000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1090000    3.10900  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.109 2.99302 2.85902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109000000000e+00, best bound 3.109000000000e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xa3d01a5d
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8930206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0270204
#
# Root relaxation: objective 3.143000e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1430000    3.14300  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.143 3.02702 2.89302
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.143000000000e+00, best bound 3.143000000000e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc52701b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8590206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9930204
#
# Root relaxation: objective 3.109000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1090000    3.10900  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.109 2.99302 2.85902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109000000000e+00, best bound 3.109000000000e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 429 rows, 360 columns and 1080 nonzeros
# Model fingerprint: 0x010fc20b
# Variable types: 0 continuous, 360 integer (360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2139.8778435
# Presolve removed 427 rows and 357 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 3 columns, 4 nonzeros
# Found heuristic solution: objective 2510.5360954
# Variable types: 0 continuous, 3 integer (3 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2510.54 2139.88
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.510536095405e+03, best bound 2.510536095405e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc52701b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8590206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9930204
#
# Root relaxation: objective 3.109000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1090000    3.10900  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.109 2.99302 2.85902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109000000000e+00, best bound 3.109000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xa3d01a5d
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8930206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0270204
#
# Root relaxation: objective 3.143000e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1430000    3.14300  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.143 3.02702 2.89302
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.143000000000e+00, best bound 3.143000000000e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc52701b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8590206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9930204
#
# Root relaxation: objective 3.109000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1090000    3.10900  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.109 2.99302 2.85902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109000000000e+00, best bound 3.109000000000e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 745 rows, 600 columns and 1920 nonzeros
# Model fingerprint: 0x4997c05c
# Variable types: 0 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 3458.6456262
# Presolve removed 734 rows and 585 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 4005.9482825
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4005.95 3458.65
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.005948282519e+03, best bound 4.005948282519e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc52701b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8590206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9930204
#
# Root relaxation: objective 3.109000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1090000    3.10900  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.109 2.99302 2.85902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109000000000e+00, best bound 3.109000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xa3d01a5d
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8930206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0270204
#
# Root relaxation: objective 3.143000e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1430000    3.14300  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.143 3.02702 2.89302
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.143000000000e+00, best bound 3.143000000000e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xa3d01a5d
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8930206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0270204
#
# Root relaxation: objective 3.143000e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1430000    3.14300  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.143 3.02702 2.89302
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.143000000000e+00, best bound 3.143000000000e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc52701b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8590206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9930204
#
# Root relaxation: objective 3.109000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1090000    3.10900  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.109 2.99302 2.85902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109000000000e+00, best bound 3.109000000000e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc52701b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8590206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9930204
#
# Root relaxation: objective 3.109000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1090000    3.10900  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.109 2.99302 2.85902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109000000000e+00, best bound 3.109000000000e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 143 rows, 120 columns and 360 nonzeros
# Model fingerprint: 0x1840b18e
# Variable types: 0 continuous, 120 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 715.0466512
# Presolve removed 141 rows and 117 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 3 columns, 4 nonzeros
# Found heuristic solution: objective 836.5866892
# Variable types: 0 continuous, 3 integer (3 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 836.587 715.047
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.365866891862e+02, best bound 8.365866891862e+02, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 0 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc52701b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8590206
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9930204
#
# Root relaxation: objective 3.109000e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1090000    3.10900  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.109 2.99302 2.85902
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109000000000e+00, best bound 3.109000000000e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====

# %%
weekResult = pd.DataFrame(allResult, index=[1, 2, 3, 4, 5, 6, 7, 8, 9, "stage 1", "stage 1 wAVG", "stage 2"])
weekResult.to_csv("result/" + aTeam + ".csv", encoding='utf_8_sig')

# %% [markdown]
# #### 味全龍

# %%
aTeam = "味全龍"
scheduleList = {}
with open(scheduleRoot + aTeam + ".csv", encoding="utf-8") as csvFile:
    csvReader = csv.DictReader(csvFile)
    for row in csvReader:
        scheduleList[row["日期"]] = row

scheduleByWeek = {}
for week in range(1, 8):
    scheduleByWeek[week] = []
    for date in scheduleList.keys():
        if scheduleList[date]["\ufeff週次"] == str(week):
            scheduleByWeek[week].append({
                "date": datetime.strptime(date, "%m月%d日").date().replace(year=2022),
                "field": "".join(scheduleList[date]["場地"].split()),
                "oppo": "".join(scheduleList[date]["對手"].split()),
                "pitcher": "".join(scheduleList[date]["先發投手"].split())
            })

allResult = {}
for week in range(1, 8):
    aMonth = "Apr"
    aGame = scheduleByWeek[week]
    playerName, onPlayer, stage1Obj, stage1ObjWeight = stage1(aTeam, aGame, aMonth)
    onPlayer, playerName = stageDH(aTeam, aGame, aMonth, playerName, onPlayer)
    onPlayer, playerName, stage2Obj = stage2(aTeam, aGame, onPlayer, playerName)

    index = 0
    for date, dayPlayer in onPlayer.items():
        onPlayerList = [None] * 9
        for playerName, playerData in dayPlayer.items():
            onPlayerList[playerData["bat"] - 1] = playerName + " " + fieldMap[playerData["field"]]
        onPlayerList.extend([stage1Obj, stage1ObjWeight, stage2Obj[index]])
        onPlayer[date] = onPlayerList
        index += 1
    allResult.update(onPlayer)

weekResult = pd.DataFrame(allResult, index=[1, 2, 3, 4, 5, 6, 7, 8, 9, "stage 1", "stage 1 wAVG", "stage 2"])
weekResult.to_csv("result/" + aTeam + ".csv", encoding='utf_8_sig')
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 143 rows, 120 columns and 360 nonzeros
# Model fingerprint: 0x5b637288
# Variable types: 0 continuous, 120 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 667.8391602
# Presolve removed 135 rows and 108 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 12 columns, 24 nonzeros
# Found heuristic solution: objective 709.8687121
# Variable types: 0 continuous, 12 integer (12 binary)
# Found heuristic solution: objective 746.1270919
#
# Root relaxation: objective 7.478223e+02, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     747.8223079  747.82231  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 747.822 746.127 709.869 667.839
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.478223078712e+02, best bound 7.478223078712e+02, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 0 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x91d63cb3
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6615568
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8231429
#
# Root relaxation: objective 2.850926e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8509259    2.85093  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.85093 2.82314 2.66156
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.850925925926e+00, best bound 2.850925925926e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 438 rows, 368 columns and 1104 nonzeros
# Model fingerprint: 0x85b63ae1
# Variable types: 0 continuous, 368 integer (368 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1875.1634721
# Presolve removed 430 rows and 356 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 12 columns, 24 nonzeros
# Found heuristic solution: objective 2066.2846122
# Variable types: 0 continuous, 12 integer (12 binary)
# Found heuristic solution: objective 2101.7174137
#
# Root relaxation: objective 2.103465e+03, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2103.4653581 2103.46536  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2103.47 2101.72 2066.28 1875.16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.103465358097e+03, best bound 2.103465358097e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x384ad394
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6934140
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8550000
#
# Root relaxation: objective 2.863926e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8639259    2.86393  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.86393 2.855 2.69341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.863925925926e+00, best bound 2.863925925926e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x384ad394
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6934140
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8550000
#
# Root relaxation: objective 2.863926e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8639259    2.86393  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.86393 2.855 2.69341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.863925925926e+00, best bound 2.863925925926e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc9a89545
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7489915
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8193571
#
# Root relaxation: objective 2.850926e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8509259    2.85093  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.85093 2.81936 2.74899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.850925925926e+00, best bound 2.850925925926e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 756 rows, 608 columns and 1944 nonzeros
# Model fingerprint: 0x414bdd0f
# Variable types: 0 continuous, 608 integer (608 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2717.3652219
# Presolve removed 745 rows and 593 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 3114.7826521
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 3.115024e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      3114.78265 3115.02413  0.01%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3114.78 2717.37
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.114782652127e+03, best bound 3.115024130119e+03, gap 0.0078%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc9a89545
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7489915
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8193571
#
# Root relaxation: objective 2.850926e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8509259    2.85093  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.85093 2.81936 2.74899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.850925925926e+00, best bound 2.850925925926e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xcd898252
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6335953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7039609
#
# Root relaxation: objective 2.840926e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8409259    2.84093  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.84093 2.70396 2.6336
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.840925925926e+00, best bound 2.840925925926e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xcd898252
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6335953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7039609
#
# Root relaxation: objective 2.840926e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8409259    2.84093  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.84093 2.70396 2.6336
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.840925925926e+00, best bound 2.840925925926e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x5be13784
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.5197953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7259915
#
# Root relaxation: objective 2.827926e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8279259    2.82793  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.82793 2.72599 2.5198
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.827925925926e+00, best bound 2.827925925926e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xc46d85fe
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7983244
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9209697
#
# Root relaxation: objective 2.927926e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9279259    2.92793  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.92793 2.92097 2.79832
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.927925925926e+00, best bound 2.927925925926e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 745 rows, 600 columns and 1920 nonzeros
# Model fingerprint: 0xb7ac5e60
# Variable types: 0 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2889.6775227
# Presolve removed 734 rows and 585 columns
# Presolve time: 0.01s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 3228.9302256
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 3.230494e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3230.4942874 3230.49429  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3230.49 3228.93 2889.68
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.230494287417e+03, best bound 3.230494287417e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x9b432bd9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.5567953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7538988
#
# Root relaxation: objective 2.924411e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9244108    2.92441  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.92441 2.7539 2.5568
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.924410774411e+00, best bound 2.924410774411e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 429 rows, 360 columns and 1080 nonzeros
# Model fingerprint: 0x1b6efc73
# Variable types: 0 continuous, 360 integer (360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1815.0184412
# Presolve removed 421 rows and 349 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 11 columns, 22 nonzeros
# Found heuristic solution: objective 1973.9048901
# Variable types: 0 continuous, 11 integer (11 binary)
#
# Root relaxation: objective 1.974844e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1974.8440053 1974.84401  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1974.84 1973.9 1815.02
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.974844005255e+03, best bound 1.974844005255e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 286 rows, 240 columns and 720 nonzeros
# Model fingerprint: 0xc938ebf7
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1283.5363176
# Presolve removed 278 rows and 229 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 11 columns, 22 nonzeros
# Found heuristic solution: objective 1410.0814163
# Variable types: 0 continuous, 11 integer (11 binary)
#
# Root relaxation: objective 1.412516e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1412.5164780 1412.51648  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1412.52 1410.08 1283.54
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.412516478034e+03, best bound 1.412516478034e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x4229299a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6705953
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409609
#
# Root relaxation: objective 2.937411e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9374108    2.93741  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.93741 2.74096 2.6706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.937410774411e+00, best bound 2.937410774411e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 999 rows, 800 columns and 2601 nonzeros
# Model fingerprint: 0x5f4561b7
# Variable types: 0 continuous, 800 integer (800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 3480.4256361
# Presolve removed 981 rows and 776 columns
# Presolve time: 0.01s
# Presolved: 18 rows, 24 columns, 72 nonzeros
# Found heuristic solution: objective 3798.9950423
# Variable types: 0 continuous, 24 integer (24 binary)
#
# Root relaxation: objective 3.800522e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3800.5215704 3800.52157  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3800.52 3799 3480.43
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.800521570387e+03, best bound 3.800521570387e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 5 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# ===== complete game 5 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb38212b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6167078
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.6870735
#
# Root relaxation: objective 2.840926e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8409259    2.84093  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.84093 2.68707 2.61671
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.840925925926e+00, best bound 2.840925925926e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb38212b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6167078
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.6870735
#
# Root relaxation: objective 2.840926e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8409259    2.84093  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.84093 2.68707 2.61671
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.840925925926e+00, best bound 2.840925925926e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x96e3e92a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.5347650
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.7409612
#
# Root relaxation: objective 2.840926e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8409259    2.84093  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.84093 2.74096 2.53476
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.840925925926e+00, best bound 2.840925925926e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb38212b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6167078
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.6870735
#
# Root relaxation: objective 2.840926e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8409259    2.84093  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.84093 2.68707 2.61671
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.840925925926e+00, best bound 2.840925925926e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb38212b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6167078
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.6870735
#
# Root relaxation: objective 2.840926e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8409259    2.84093  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.84093 2.68707 2.61671
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.840925925926e+00, best bound 2.840925925926e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xb38212b9
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6167078
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.6870735
#
# Root relaxation: objective 2.840926e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.8409259    2.84093  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.84093 2.68707 2.61671
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.840925925926e+00, best bound 2.840925925926e+00, gap 0.0000%
# ===== complete game 5 - stage 2 =====

# %% [markdown]
# #### 樂天桃猿

# %%
aTeam = "樂天桃猿"
scheduleList = {}
with open(scheduleRoot + aTeam + ".csv", encoding="utf-8") as csvFile:
    csvReader = csv.DictReader(csvFile)
    for row in csvReader:
        scheduleList[row["日期"]] = row

scheduleByWeek = {}
for week in range(1, 9):
    scheduleByWeek[week] = []
    for date in scheduleList.keys():
        if scheduleList[date]["\ufeff週次"] == str(week):
            scheduleByWeek[week].append({
                "date": datetime.strptime(date, "%m月%d日").date().replace(year=2022),
                "field": "".join(scheduleList[date]["場地"].split()),
                "oppo": "".join(scheduleList[date]["對手"].split()),
                "pitcher": "".join(scheduleList[date]["先發投手"].split())
            })

allResult = {}
for week in range(1, 9):
    aMonth = "Apr"
    aGame = scheduleByWeek[week]
    playerName, onPlayer, stage1Obj, stage1ObjWeight = stage1(aTeam, aGame, aMonth)
    onPlayer, playerName = stageDH(aTeam, aGame, aMonth, playerName, onPlayer)
    onPlayer, playerName, stage2Obj = stage2(aTeam, aGame, onPlayer, playerName)

    index = 0
    for date, dayPlayer in onPlayer.items():
        onPlayerList = [None] * 9
        for playerName, playerData in dayPlayer.items():
            onPlayerList[playerData["bat"] - 1] = playerName + " " + fieldMap[playerData["field"]]
        onPlayerList.extend([stage1Obj, stage1ObjWeight, stage2Obj[index]])
        onPlayer[date] = onPlayerList
        index += 1
    allResult.update(onPlayer)

weekResult = pd.DataFrame(allResult, index=[1, 2, 3, 4, 5, 6, 7, 8, 9, "stage 1", "stage 1 wAVG", "stage 2"])
weekResult.to_csv("result/" + aTeam + ".csv", encoding='utf_8_sig')
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 709 rows, 568 columns and 1817 nonzeros
# Model fingerprint: 0xc2e67b1f
# Variable types: 0 continuous, 568 integer (568 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 4130.4605633
# Presolve removed 702 rows and 556 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 12 columns, 24 nonzeros
# Found heuristic solution: objective 4627.0715434
# Variable types: 0 continuous, 12 integer (12 binary)
#
# Root relaxation: objective 4.634674e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4634.6743308 4634.67433  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4634.67 4627.07 4130.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.634674330767e+03, best bound 4.634674330767e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xe78bd105
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.2480000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
#
# Root relaxation: objective 3.320058e+00, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3200577    3.32006  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.32006 3.248
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.320057692308e+00, best bound 3.320057692308e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x7dce6ad6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1310000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
#
# Root relaxation: objective 3.203058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2030577    3.20306  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.20306 3.131
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203057692308e+00, best bound 3.203057692308e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x29cbe256
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0282479
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1310000
#
# Root relaxation: objective 3.203058e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2030577    3.20306  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.20306 3.131 3.02825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203057692308e+00, best bound 3.203057692308e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x29cbe256
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0282479
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1310000
#
# Root relaxation: objective 3.203058e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2030577    3.20306  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.20306 3.131 3.02825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203057692308e+00, best bound 3.203057692308e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x29cbe256
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0282479
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1310000
#
# Root relaxation: objective 3.203058e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2030577    3.20306  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.20306 3.131 3.02825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203057692308e+00, best bound 3.203057692308e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 698 rows, 560 columns and 1791 nonzeros
# Model fingerprint: 0x5ed83dbc
# Variable types: 0 continuous, 560 integer (560 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 3572.2458670
# Presolve removed 687 rows and 545 columns
# Presolve time: 0.01s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 3965.7554724
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3965.76 3572.25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.965755472436e+03, best bound 3.965755472436e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x29cbe256
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0282479
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1310000
#
# Root relaxation: objective 3.203058e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2030577    3.20306  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.20306 3.131 3.02825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203057692308e+00, best bound 3.203057692308e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x29cbe256
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0282479
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1310000
#
# Root relaxation: objective 3.203058e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2030577    3.20306  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.20306 3.131 3.02825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203057692308e+00, best bound 3.203057692308e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x29cbe256
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0282479
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1310000
#
# Root relaxation: objective 3.203058e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2030577    3.20306  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.20306 3.131 3.02825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203057692308e+00, best bound 3.203057692308e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x7dce6ad6
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1310000
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
#
# Root relaxation: objective 3.203058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2030577    3.20306  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3.20306 3.131
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.203057692308e+00, best bound 3.203057692308e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfe004654
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0432880
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.04329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 550 rows, 448 columns and 1400 nonzeros
# Model fingerprint: 0x2c16a2e4
# Variable types: 0 continuous, 448 integer (448 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 3554.9989877
# Presolve removed 546 rows and 443 columns
# Presolve time: 0.01s
# Presolved: 4 rows, 5 columns, 9 nonzeros
# Found heuristic solution: objective 3895.5934036
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3895.59 3555
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.895593403561e+03, best bound 3.895593403561e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfe004654
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0432880
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.04329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfe004654
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0432880
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.04329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfe004654
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0432880
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.04329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x69510191
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1460401
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.14604
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 550 rows, 448 columns and 1400 nonzeros
# Model fingerprint: 0xf94c37ac
# Variable types: 0 continuous, 448 integer (448 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 3329.8872415
# Presolve removed 546 rows and 443 columns
# Presolve time: 0.01s
# Presolved: 4 rows, 5 columns, 9 nonzeros
# Found heuristic solution: objective 3661.9029157
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3661.9 3329.89
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.661902915654e+03, best bound 3.661902915654e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x69510191
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1460401
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.14604
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfe004654
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0432880
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.04329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfe004654
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0432880
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.04329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfe004654
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.0432880
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1880000
#
# Root relaxation: objective 3.276836e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2768361    3.27684  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27684 3.188 3.04329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.276836065574e+00, best bound 3.276836065574e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 402 rows, 336 columns and 1008 nonzeros
# Model fingerprint: 0xdcc0f1af
# Variable types: 0 continuous, 336 integer (336 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2210.2560651
# Presolve removed 396 rows and 328 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2416.1159355
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 2.417199e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2417.1992404 2417.19924  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2417.2 2416.12 2210.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.417199240396e+03, best bound 2.417199240396e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xff39331a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xff39331a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xff39331a
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 698 rows, 560 columns and 1792 nonzeros
# Model fingerprint: 0x33285f1a
# Variable types: 0 continuous, 560 integer (560 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 3999.7820282
# Presolve removed 687 rows and 545 columns
# Presolve time: 0.02s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 4330.6624679
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 4.332547e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4332.5473969 4332.54740  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4332.55 4330.66 3999.78
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.332547396929e+03, best bound 4.332547396929e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x5520e887
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1590401
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2010000
#
# Root relaxation: objective 3.273058e+00, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2730577    3.27306  0.00%     -    0s
#
# Explored 1 nodes (21 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.27306 3.201 3.15904
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.273057692308e+00, best bound 3.273057692308e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 698 rows, 560 columns and 1792 nonzeros
# Model fingerprint: 0x112d8a71
# Variable types: 0 continuous, 560 integer (560 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [9e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 4048.0038085
# Presolve removed 687 rows and 545 columns
# Presolve time: 0.01s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 4388.9891686
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 4.395856e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4395.8562770 4395.85628  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4395.86 4388.99 4048
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.395856277001e+03, best bound 4.395856277001e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0b58a571
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1910401
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2330000
#
# Root relaxation: objective 3.305058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3050577    3.30506  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.30506 3.233 3.19104
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.305057692308e+00, best bound 3.305057692308e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 134 rows, 112 columns and 336 nonzeros
# Model fingerprint: 0x1ee0465c
# Variable types: 0 continuous, 112 integer (112 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 998.7989586
# Presolve removed 128 rows and 104 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 1072.6365295
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 1.074581e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1074.5810832 1074.58108  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1074.58 1072.64 998.799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.074581083247e+03, best bound 1.074581083247e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 0 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x82647704
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 3.1957782
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.2490000
#
# Root relaxation: objective 3.321058e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.3210577    3.32106  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.32106 3.249 3.19578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.321057692308e+00, best bound 3.321057692308e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====

# %% [markdown]
# #### 統一7-ELEVEn獅

# %%
aTeam = "統一7-ELEVEn獅"
scheduleList = {}
with open(scheduleRoot + aTeam + ".csv", encoding="utf-8") as csvFile:
    csvReader = csv.DictReader(csvFile)
    for row in csvReader:
        scheduleList[row["日期"]] = row

scheduleByWeek = {}
for week in range(1, 9):
    scheduleByWeek[week] = []
    for date in scheduleList.keys():
        if scheduleList[date]["\ufeff週次"] == str(week):
            scheduleByWeek[week].append({
                "date": datetime.strptime(date, "%m月%d日").date().replace(year=2022),
                "field": "".join(scheduleList[date]["場地"].split()),
                "oppo": "".join(scheduleList[date]["對手"].split()),
                "pitcher": "".join(scheduleList[date]["先發投手"].split())
            })

allResult = {}
for week in range(1, 9):
    aMonth = "Apr"
    aGame = scheduleByWeek[week]
    playerName, onPlayer, stage1Obj, stage1ObjWeight = stage1(aTeam, aGame, aMonth)
    onPlayer, playerName = stageDH(aTeam, aGame, aMonth, playerName, onPlayer)
    onPlayer, playerName, stage2Obj = stage2(aTeam, aGame, onPlayer, playerName)

    index = 0
    for date, dayPlayer in onPlayer.items():
        onPlayerList = [None] * 9
        for playerName, playerData in dayPlayer.items():
            onPlayerList[playerData["bat"] - 1] = playerName + " " + fieldMap[playerData["field"]]
        onPlayerList.extend([stage1Obj, stage1ObjWeight, stage2Obj[index]])
        onPlayer[date] = onPlayerList
        index += 1
    allResult.update(onPlayer)

weekResult = pd.DataFrame(allResult, index=[1, 2, 3, 4, 5, 6, 7, 8, 9, "stage 1", "stage 1 wAVG", "stage 2"])
weekResult.to_csv("result/" + aTeam + ".csv", encoding='utf_8_sig')
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 268 rows, 224 columns and 672 nonzeros
# Model fingerprint: 0xe16b2762
# Variable types: 0 continuous, 224 integer (224 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 939.7817409
# Presolve removed 263 rows and 218 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 6 columns, 12 nonzeros
# Found heuristic solution: objective 1443.7753191
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 1.443937e+03, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1443.9371262 1443.93713  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1443.94 1443.78 939.782
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.443937126174e+03, best bound 1.443937126174e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xdcebe561
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 5e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9789670
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1207071
#
# Root relaxation: objective 3.281472e+00, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2814724    3.28147  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.28147 3.12071 2.97897
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.281472409311e+00, best bound 3.281472409311e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xdcebe561
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 5e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9789670
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1207071
#
# Root relaxation: objective 3.281472e+00, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2814724    3.28147  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.28147 3.12071 2.97897
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.281472409311e+00, best bound 3.281472409311e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 541 rows, 440 columns and 1372 nonzeros
# Model fingerprint: 0x5514a7d5
# Variable types: 0 continuous, 440 integer (440 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 1682.8149678
# Presolve removed 535 rows and 432 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2600.2436808
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2600.24 1682.81
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600243680782e+03, best bound 2.600243680782e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xdcebe561
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 5e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9789670
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.1207071
#
# Root relaxation: objective 3.281472e+00, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2814724    3.28147  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.28147 3.12071 2.97897
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.281472409311e+00, best bound 3.281472409311e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0de3c421
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 5e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7494300
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8911700
#
# Root relaxation: objective 3.212472e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2124724    3.21247  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.21247 2.89117 2.74943
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.212472409311e+00, best bound 3.212472409311e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x8f630f23
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 5e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.9329670
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0747071
#
# Root relaxation: objective 3.235472e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.2354724    3.23547  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.23547 3.07471 2.93297
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.235472409311e+00, best bound 3.235472409311e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xfb4ddc59
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 5e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8652633
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0070034
#
# Root relaxation: objective 3.181634e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1816337    3.18163  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.18163 3.007 2.86526
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.181633699634e+00, best bound 3.181633699634e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 734 rows, 592 columns and 1885 nonzeros
# Model fingerprint: 0x077ec433
# Variable types: 0 continuous, 592 integer (592 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2622.4937797
# Presolve removed 728 rows and 584 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 3540.7338167
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 3.543483e+03, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3543.4825267 3543.48253  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3543.48 3540.73 2622.49
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.543482526667e+03, best bound 3.543482526667e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x7fb740aa
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6582633
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8000034
#
# Root relaxation: objective 2.974634e+00, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.9746337    2.97463  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2.97463 2.8 2.65826
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.974633699634e+00, best bound 2.974633699634e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xade647ce
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7468993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9567071
#
# Root relaxation: objective 3.085634e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0856337    3.08563  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.08563 2.95671 2.7469
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.085633699634e+00, best bound 3.085633699634e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xade647ce
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7468993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9567071
#
# Root relaxation: objective 3.085634e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0856337    3.08563  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.08563 2.95671 2.7469
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.085633699634e+00, best bound 3.085633699634e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x608fa59f
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7438993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9537071
#
# Root relaxation: objective 3.069538e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0695385    3.06954  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.06954 2.95371 2.7439
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.069538461538e+00, best bound 3.069538461538e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x608fa59f
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7438993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9537071
#
# Root relaxation: objective 3.069538e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0695385    3.06954  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.06954 2.95371 2.7439
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.069538461538e+00, best bound 3.069538461538e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 587 rows, 480 columns and 1491 nonzeros
# Model fingerprint: 0xf8204936
# Variable types: 0 continuous, 480 integer (480 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2108.4845659
# Presolve removed 580 rows and 468 columns
# Presolve time: 0.01s
# Presolved: 7 rows, 12 columns, 24 nonzeros
# Found heuristic solution: objective 3142.6503177
# Variable types: 0 continuous, 12 integer (12 binary)
#
# Root relaxation: objective 3.164522e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3164.5217125 3164.52171  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3164.52 3142.65 2108.48
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.164521712522e+03, best bound 3.164521712522e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x608fa59f
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7438993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9537071
#
# Root relaxation: objective 3.069538e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0695385    3.06954  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.06954 2.95371 2.7439
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.069538461538e+00, best bound 3.069538461538e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x3819c135
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.4880029
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0271935
#
# Root relaxation: objective 3.065538e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0655385    3.06554  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.06554 3.02719 2.488
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.065538461538e+00, best bound 3.065538461538e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x0f3a29e5
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8079670
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9497071
#
# Root relaxation: objective 3.065538e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0655385    3.06554  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.06554 2.94971 2.80797
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.065538461538e+00, best bound 3.065538461538e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x3819c135
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.4880029
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 3.0271935
#
# Root relaxation: objective 3.065538e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0655385    3.06554  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.06554 3.02719 2.488
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.065538461538e+00, best bound 3.065538461538e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 745 rows, 600 columns and 1920 nonzeros
# Model fingerprint: 0xc3921ab8
# Variable types: 0 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2467.8430844
# Presolve removed 734 rows and 585 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 15 columns, 39 nonzeros
# Found heuristic solution: objective 2952.1815329
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 2.968974e+03, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2968.9744569 2968.97446  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2968.97 2952.18 2467.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.968974456883e+03, best bound 2.968974456883e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x70befd34
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6798993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.6799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xcbd753d3
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7479670
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.74797
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x70befd34
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6798993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.6799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x70befd34
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6798993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.6799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x70befd34
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6798993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.6799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 429 rows, 360 columns and 1080 nonzeros
# Model fingerprint: 0x228af3a3
# Variable types: 0 continuous, 360 integer (360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2081.1447495
# Presolve removed 424 rows and 354 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 6 columns, 12 nonzeros
# Found heuristic solution: objective 2497.0952490
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2497.09525 2497.09525  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2497.1 2081.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.497095248963e+03, best bound 2.497095248963e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x70befd34
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6798993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.6799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x70befd34
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6798993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.6799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x70befd34
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6798993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.6799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 605 rows, 496 columns and 1545 nonzeros
# Model fingerprint: 0x62a946b4
# Variable types: 0 continuous, 496 integer (496 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2165.9494545
# Presolve removed 600 rows and 490 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 6 columns, 12 nonzeros
# Found heuristic solution: objective 2909.6773181
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2909.67732 2909.67732  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2909.68 2165.95
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.909677318067e+03, best bound 2.909677318067e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x70befd34
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.6798993
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.8897071
#
# Root relaxation: objective 3.018634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0186337    3.01863  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.01863 2.88971 2.6799
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018633699634e+00, best bound 3.018633699634e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x5a019a8f
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7752633
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9627071
#
# Root relaxation: objective 3.091634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0916337    3.09163  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.09163 2.96271 2.77526
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.091633699634e+00, best bound 3.091633699634e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0xd292286d
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8349670
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9767071
#
# Root relaxation: objective 3.105634e+00, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.1056337    3.10563  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.10563 2.97671 2.83497
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.105633699634e+00, best bound 3.105633699634e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x5a019a8f
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7752633
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9627071
#
# Root relaxation: objective 3.091634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0916337    3.09163  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.09163 2.96271 2.77526
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.091633699634e+00, best bound 3.091633699634e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 765 rows, 616 columns and 1969 nonzeros
# Model fingerprint: 0x3db7e0e5
# Variable types: 0 continuous, 616 integer (616 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 2706.3949162
# Presolve removed 756 rows and 606 columns
# Presolve time: 0.00s
# Presolved: 9 rows, 10 columns, 26 nonzeros
# Found heuristic solution: objective 3810.4502459
# Variable types: 0 continuous, 10 integer (10 binary)
#
# Root relaxation: cutoff, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3810.45025 3810.45025  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3810.45 2706.39
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.810450245921e+03, best bound 3.810450245921e+03, gap 0.0000%
# ===== complete game 0 - stage 1 =====
# ===== complete game 1 - stage 1 =====
# ===== complete game 2 - stage 1 =====
# ===== complete game 3 - stage 1 =====
# ===== complete game 4 - stage 1 =====
# ===== complete game 0 - stage DH =====
# ===== complete game 1 - stage DH =====
# ===== complete game 2 - stage DH =====
# ===== complete game 3 - stage DH =====
# ===== complete game 4 - stage DH =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x5a019a8f
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7752633
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9627071
#
# Root relaxation: objective 3.091634e+00, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0916337    3.09163  0.00%     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.09163 2.96271 2.77526
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.091633699634e+00, best bound 3.091633699634e+00, gap 0.0000%
# ===== complete game 0 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x2495d4e3
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7552633
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9427071
#
# Root relaxation: objective 3.071634e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0716337    3.07163  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.07163 2.94271 2.75526
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.071633699634e+00, best bound 3.071633699634e+00, gap 0.0000%
# ===== complete game 1 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x2495d4e3
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7552633
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9427071
#
# Root relaxation: objective 3.071634e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0716337    3.07163  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.07163 2.94271 2.75526
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.071633699634e+00, best bound 3.071633699634e+00, gap 0.0000%
# ===== complete game 2 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x8f158c18
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.8009670
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9427071
#
# Root relaxation: objective 3.071634e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0716337    3.07163  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.07163 2.94271 2.80097
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.071633699634e+00, best bound 3.071633699634e+00, gap 0.0000%
# ===== complete game 3 - stage 2 =====
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 81 columns and 153 nonzeros
# Model fingerprint: 0x2495d4e3
# Variable types: 0 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.7552633
# Presolve removed 0 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 72 columns, 144 nonzeros
# Variable types: 0 continuous, 72 integer (72 binary)
# Found heuristic solution: objective 2.9427071
#
# Root relaxation: objective 3.071634e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0716337    3.07163  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.07163 2.94271 2.75526
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.071633699634e+00, best bound 3.071633699634e+00, gap 0.0000%
# ===== complete game 4 - stage 2 =====
